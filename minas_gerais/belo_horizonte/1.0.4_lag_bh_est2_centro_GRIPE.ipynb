# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("df_final_bh_centro_GRIPE.csv")

# %%
df.head()
# Out:
#          Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0  2015-01-01       Thu             3          0      33.9      20.6
# 1  2015-01-02       Fri             4          0      32.9      21.0
# 2  2015-01-03       Sat             5          1      33.5      20.2
# 3  2015-01-04       Sun             6          1      30.6      22.2
# 4  2015-01-05       Mon             0          0      30.8      20.8
#
#    humidity_max  humidity_min  NUMBER_INT  EST2_CO  EST2_MP10  EST2_03  \
# 0          89.0          32.0          20      NaN       12.0     54.0
# 1          87.0          38.0          17      NaN       13.0     68.0
# 2          83.0          38.0          11      0.0       17.0     62.0
# 3          81.0          43.0           9      0.0       17.0     68.0
# 4          79.0          36.0          19      0.0       12.0     46.0
#
#    EST2_MP2.5  EST2_SO2
# 0         NaN       8.0
# 1         NaN      10.0
# 2         NaN      14.0
# 3         NaN      14.0
# 4         NaN       0.0

# %%
df.count()
# Out:
# Date            1826
# DayOfWeek       1826
# DayOfWeekNum    1826
# IsWeekend       1826
# temp_max        1826
# temp_min        1826
# humidity_max    1826
# humidity_min    1826
# NUMBER_INT      1826
# EST2_CO         1543
# EST2_MP10       1757
# EST2_03         1659
# EST2_MP2.5      1183
# EST2_SO2        1703
# dtype: int64

# %% [markdown]
# # LAG - CO

# %%
selected_cols_co = [
    'Date',
    'NUMBER_INT',
    'EST2_CO'
]

df_selected_co = df[selected_cols_co].copy()

# %%
df_selected_co.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# EST2_CO       1543
# dtype: int64

# %%
# df_selected_co = df_selected_co.dropna()

# %%
df_selected_co['EST2_CO_lag1'] = df_selected_co['EST2_CO'].shift(1)
df_selected_co['EST2_CO_lag2'] = df_selected_co['EST2_CO'].shift(2)
df_selected_co['EST2_CO_lag3'] = df_selected_co['EST2_CO'].shift(3)
df_selected_co['EST2_CO_lag4'] = df_selected_co['EST2_CO'].shift(4)
df_selected_co['EST2_CO_lag5'] = df_selected_co['EST2_CO'].shift(5)
df_selected_co['EST2_CO_lag6'] = df_selected_co['EST2_CO'].shift(6)
df_selected_co['EST2_CO_lag7'] = df_selected_co['EST2_CO'].shift(7)

# df_selected_co = df_selected_co.reset_index(drop=True)

# %%
# df_selected_co = df_selected_co.dropna()

# %%
df_selected_co.count()
# Out:
# Date            1826
# NUMBER_INT      1826
# EST2_CO         1543
# EST2_CO_lag1    1542
# EST2_CO_lag2    1541
# EST2_CO_lag3    1540
# EST2_CO_lag4    1539
# EST2_CO_lag5    1538
# EST2_CO_lag6    1537
# EST2_CO_lag7    1536
# dtype: int64

# %%
correlation_matrix = df_selected_co.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - **SO2**

# %%
selected_cols_so2 = [
    'Date',
    'NUMBER_INT',
    'EST2_SO2'
]

df_selected_so2 = df[selected_cols_so2].copy()
# df_selected_so2 = df_selected_so2.dropna()

# %%
df_selected_so2['EST2_SO2_lag1'] = df_selected_so2['EST2_SO2'].shift(1)
df_selected_so2['EST2_SO2_lag2'] = df_selected_so2['EST2_SO2'].shift(2)
df_selected_so2['EST2_SO2_lag3'] = df_selected_so2['EST2_SO2'].shift(3)
df_selected_so2['EST2_SO2_lag4'] = df_selected_so2['EST2_SO2'].shift(4)
df_selected_so2['EST2_SO2_lag5'] = df_selected_so2['EST2_SO2'].shift(5)
df_selected_so2['EST2_SO2_lag6'] = df_selected_so2['EST2_SO2'].shift(6)
df_selected_so2['EST2_SO2_lag7'] = df_selected_so2['EST2_SO2'].shift(7)

# df_selected_so2 = df_selected_so2.reset_index(drop=True)

# %%
# df_selected_so2 = df_selected_so2.dropna()
df_selected_so2.count()
# Out:
# Date             1826
# NUMBER_INT       1826
# EST2_SO2         1703
# EST2_SO2_lag1    1702
# EST2_SO2_lag2    1701
# EST2_SO2_lag3    1700
# EST2_SO2_lag4    1699
# EST2_SO2_lag5    1698
# EST2_SO2_lag6    1698
# EST2_SO2_lag7    1698
# dtype: int64

# %%
correlation_matrix = df_selected_so2.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - **MP2.5**

# %%
selected_cols_mp25 = [
    'Date',
    'NUMBER_INT',
    'EST2_MP2.5'
]

df_selected_mp25 = df[selected_cols_mp25].copy()
# df_selected_mp25 = df_selected_mp25.dropna()

df_selected_mp25['EST2_MP2.5_lag1'] = df_selected_mp25['EST2_MP2.5'].shift(1)
df_selected_mp25['EST2_MP2.5_lag2'] = df_selected_mp25['EST2_MP2.5'].shift(2)
df_selected_mp25['EST2_MP2.5_lag3'] = df_selected_mp25['EST2_MP2.5'].shift(3)
df_selected_mp25['EST2_MP2.5_lag4'] = df_selected_mp25['EST2_MP2.5'].shift(4)
df_selected_mp25['EST2_MP2.5_lag5'] = df_selected_mp25['EST2_MP2.5'].shift(5)
df_selected_mp25['EST2_MP2.5_lag6'] = df_selected_mp25['EST2_MP2.5'].shift(6)
df_selected_mp25['EST2_MP2.5_lag7'] = df_selected_mp25['EST2_MP2.5'].shift(7)

# df_selected_mp25 = df_selected_mp25.reset_index(drop=True)

# df_selected_mp25 = df_selected_mp25.dropna()
df_selected_mp25.count()
# Out:
# Date               1826
# NUMBER_INT         1826
# EST2_MP2.5         1183
# EST2_MP2.5_lag1    1183
# EST2_MP2.5_lag2    1183
# EST2_MP2.5_lag3    1183
# EST2_MP2.5_lag4    1183
# EST2_MP2.5_lag5    1183
# EST2_MP2.5_lag6    1183
# EST2_MP2.5_lag7    1183
# dtype: int64

# %%
correlation_matrix = df_selected_mp25.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df_selected_mp25.head()
# Out:
#          Date  NUMBER_INT  EST2_MP2.5  EST2_MP2.5_lag1  EST2_MP2.5_lag2  \
# 0  2015-01-01          20         NaN              NaN              NaN
# 1  2015-01-02          17         NaN              NaN              NaN
# 2  2015-01-03          11         NaN              NaN              NaN
# 3  2015-01-04           9         NaN              NaN              NaN
# 4  2015-01-05          19         NaN              NaN              NaN
#
#    EST2_MP2.5_lag3  EST2_MP2.5_lag4  EST2_MP2.5_lag5  EST2_MP2.5_lag6  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    EST2_MP2.5_lag7
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# # LAG - O3

# %%
selected_cols_o3 = [
    'Date',
    'NUMBER_INT',
    'EST2_03'
]

df_selected_o3 = df[selected_cols_o3].copy()
# df_selected_o3 = df_selected_o3.dropna()

df_selected_o3['EST2_03_lag1'] = df_selected_o3['EST2_03'].shift(1)
df_selected_o3['EST2_03_lag2'] = df_selected_o3['EST2_03'].shift(2)
df_selected_o3['EST2_03_lag3'] = df_selected_o3['EST2_03'].shift(3)
df_selected_o3['EST2_03_lag4'] = df_selected_o3['EST2_03'].shift(4)
df_selected_o3['EST2_03_lag5'] = df_selected_o3['EST2_03'].shift(5)
df_selected_o3['EST2_03_lag6'] = df_selected_o3['EST2_03'].shift(6)
df_selected_o3['EST2_03_lag7'] = df_selected_o3['EST2_03'].shift(7)

# df_selected_o3 = df_selected_o3.reset_index(drop=True)

# df_selected_o3 = df_selected_o3.dropna()
df_selected_o3.count()
# Out:
# Date            1826
# NUMBER_INT      1826
# EST2_03         1659
# EST2_03_lag1    1658
# EST2_03_lag2    1657
# EST2_03_lag3    1656
# EST2_03_lag4    1655
# EST2_03_lag5    1654
# EST2_03_lag6    1653
# EST2_03_lag7    1652
# dtype: int64

# %%
correlation_matrix = df_selected_o3.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - MP10

# %%
selected_cols_mp10 = [
    'Date',
    'NUMBER_INT',
    'EST2_MP10'
]

df_selected_mp10 = df[selected_cols_mp10].copy()
# df_selected_mp10 = df_selected_mp10.dropna()

df_selected_mp10['EST2_MP10_lag1'] = df_selected_mp10['EST2_MP10'].shift(1)
df_selected_mp10['EST2_MP10_lag2'] = df_selected_mp10['EST2_MP10'].shift(2)
df_selected_mp10['EST2_MP10_lag3'] = df_selected_mp10['EST2_MP10'].shift(3)
df_selected_mp10['EST2_MP10_lag4'] = df_selected_mp10['EST2_MP10'].shift(4)
df_selected_mp10['EST2_MP10_lag5'] = df_selected_mp10['EST2_MP10'].shift(5)
df_selected_mp10['EST2_MP10_lag6'] = df_selected_mp10['EST2_MP10'].shift(6)
df_selected_mp10['EST2_MP10_lag7'] = df_selected_mp10['EST2_MP10'].shift(7)

# df_selected_mp10 = df_selected_mp10.reset_index(drop=True)

# df_selected_mp10 = df_selected_mp10.dropna()
df_selected_mp10.count()
# Out:
# Date              1826
# NUMBER_INT        1826
# EST2_MP10         1757
# EST2_MP10_lag1    1756
# EST2_MP10_lag2    1755
# EST2_MP10_lag3    1754
# EST2_MP10_lag4    1753
# EST2_MP10_lag5    1752
# EST2_MP10_lag6    1751
# EST2_MP10_lag7    1750
# dtype: int64

# %%
correlation_matrix = df_selected_mp10.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - Temp

# %%
selected_cols_temp = [
    'Date',
    'NUMBER_INT',
    'temp_max',
    'temp_min'
]

df_selected_temp = df[selected_cols_temp].copy()
# df_selected_temp = df_selected_temp.dropna()

df_selected_temp['temp_max_lag1'] = df_selected_temp['temp_max'].shift(1)
df_selected_temp['temp_max_lag2'] = df_selected_temp['temp_max'].shift(2)
df_selected_temp['temp_max_lag3'] = df_selected_temp['temp_max'].shift(3)
df_selected_temp['temp_max_lag4'] = df_selected_temp['temp_max'].shift(4)
df_selected_temp['temp_max_lag5'] = df_selected_temp['temp_max'].shift(5)
df_selected_temp['temp_max_lag6'] = df_selected_temp['temp_max'].shift(6)
df_selected_temp['temp_max_lag7'] = df_selected_temp['temp_max'].shift(7)

df_selected_temp['temp_min_lag1'] = df_selected_temp['temp_min'].shift(1)
df_selected_temp['temp_min_lag2'] = df_selected_temp['temp_min'].shift(2)
df_selected_temp['temp_min_lag3'] = df_selected_temp['temp_min'].shift(3)
df_selected_temp['temp_min_lag4'] = df_selected_temp['temp_min'].shift(4)
df_selected_temp['temp_min_lag5'] = df_selected_temp['temp_min'].shift(5)
df_selected_temp['temp_min_lag6'] = df_selected_temp['temp_min'].shift(6)
df_selected_temp['temp_min_lag7'] = df_selected_temp['temp_min'].shift(7)

# df_selected_temp = df_selected_temp.reset_index(drop=True)

# df_selected_temp = df_selected_temp.dropna()
df_selected_temp.count()
# Out:
# Date             1826
# NUMBER_INT       1826
# temp_max         1826
# temp_min         1826
# temp_max_lag1    1825
# temp_max_lag2    1824
# temp_max_lag3    1823
# temp_max_lag4    1822
# temp_max_lag5    1821
# temp_max_lag6    1820
# temp_max_lag7    1819
# temp_min_lag1    1825
# temp_min_lag2    1824
# temp_min_lag3    1823
# temp_min_lag4    1822
# temp_min_lag5    1821
# temp_min_lag6    1820
# temp_min_lag7    1819
# dtype: int64

# %%
correlation_matrix = df_selected_temp.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - Humidity

# %%
selected_cols_humi = [
    'Date',
    'NUMBER_INT',
    'humidity_max',
    'humidity_min'
]

df_selected_humi = df[selected_cols_humi].copy()
# df_selected_humi = df_selected_humi.dropna()

df_selected_humi['humidity_max_lag1'] = df_selected_humi['humidity_max'].shift(1)
df_selected_humi['humidity_max_lag2'] = df_selected_humi['humidity_max'].shift(2)
df_selected_humi['humidity_max_lag3'] = df_selected_humi['humidity_max'].shift(3)
df_selected_humi['humidity_max_lag4'] = df_selected_humi['humidity_max'].shift(4)
df_selected_humi['humidity_max_lag5'] = df_selected_humi['humidity_max'].shift(5)
df_selected_humi['humidity_max_lag6'] = df_selected_humi['humidity_max'].shift(6)
df_selected_humi['humidity_max_lag7'] = df_selected_humi['humidity_max'].shift(7)

df_selected_humi['humidity_min_lag1'] = df_selected_humi['humidity_min'].shift(1)
df_selected_humi['humidity_min_lag2'] = df_selected_humi['humidity_min'].shift(2)
df_selected_humi['humidity_min_lag3'] = df_selected_humi['humidity_min'].shift(3)
df_selected_humi['humidity_min_lag4'] = df_selected_humi['humidity_min'].shift(4)
df_selected_humi['humidity_min_lag5'] = df_selected_humi['humidity_min'].shift(5)
df_selected_humi['humidity_min_lag6'] = df_selected_humi['humidity_min'].shift(6)
df_selected_humi['humidity_min_lag7'] = df_selected_humi['humidity_min'].shift(7)

# df_selected_humi = df_selected_humi.reset_index(drop=True)

# df_selected_humi = df_selected_humi.dropna()
df_selected_humi.count()
# Out:
# Date                 1826
# NUMBER_INT           1826
# humidity_max         1826
# humidity_min         1826
# humidity_max_lag1    1825
# humidity_max_lag2    1824
# humidity_max_lag3    1823
# humidity_max_lag4    1822
# humidity_max_lag5    1821
# humidity_max_lag6    1820
# humidity_max_lag7    1819
# humidity_min_lag1    1825
# humidity_min_lag2    1824
# humidity_min_lag3    1823
# humidity_min_lag4    1822
# humidity_min_lag5    1821
# humidity_min_lag6    1820
# humidity_min_lag7    1819
# dtype: int64

# %%
correlation_matrix = df_selected_humi.select_dtypes(include='number').corr()
plt.figure(figsize=(16, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
