# %% [markdown]
# # Pointwise R. - Dens Local F.
# ## RF

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# https://towardsdatascience.com/gowers-distance-for-mixed-categorical-and-numerical-data-799fedd1080c/
import gower

# %%
# --- Metrics ---
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def smape(y_true, y_pred):
    return 100/len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# %%
df = pd.read_csv("df_final_bh_amazonas.csv")
selected_cols_final = [
    'Date',
    'DayOfWeekNum',
    'WeekOfYear',
    'Month',
    'IsWeekend',
    'IsHoliday',
    'NUMBER_INT',
    'temp_max',
    'temp_min',
    'humidity_max',
]

df_final = df[selected_cols_final].copy()
df_final = df_final.dropna()


# Marking categorical columns
categorical_cols = ['DayOfWeekNum', 'WeekOfYear', 'Month', 'IsWeekend', 'IsHoliday']
for col in categorical_cols:
    df_final[col] = df_final[col].astype('object')
df_final.dtypes
# Out:
# Date             object
# DayOfWeekNum     object
# WeekOfYear       object
# Month            object
# IsWeekend        object
# IsHoliday        object
# NUMBER_INT        int64
# temp_max        float64
# temp_min        float64
# humidity_max    float64
# dtype: object

# %%
# Simulate what gower_matrix does internally
is_number = np.vectorize(lambda x: not np.issubdtype(x, np.number))
cat_features_mask = is_number(df_final.dtypes)
print(cat_features_mask)
# Out:
# [ True  True  True  True  True  True False False False False]

# %%
df_final['Date'] = pd.to_datetime(df_final['Date'])

# remove the last 5 days (account for lag ...)
df_final = df_final[:-5]

# Range for training and testing (4 years for training, 1 year for validation)
min_year = df_final['Date'].dt.year.min()
train_mask = df_final['Date'].dt.year < (min_year + 4)
val_mask = df_final['Date'].dt.year == (min_year + 4)


df_train = df_final[train_mask]
df_val = df_final[val_mask]

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)


print(f"Training set size: {df_train.count()} rows")
print(f"Validation set size: {df_val.count()} rows")
print(f"Training set date range: {df_train['Date'].min()} to {df_train['Date'].max()}")
print(f"Validation set date range: {df_val['Date'].min()} to {df_val['Date'].max()}")

df_train = df_train.drop(columns=['Date'])
df_val = df_val.drop(columns=['Date'])

X = df_final.drop(columns=['Date', 'NUMBER_INT'])
y = df_final['NUMBER_INT']


X_train = df_train.drop(columns=['NUMBER_INT'])
y_train = df_train['NUMBER_INT']

X_val = df_val.drop(columns=['NUMBER_INT'])
y_val = df_val['NUMBER_INT']
# Out:
# Training set size: Date            1461
# DayOfWeekNum    1461
# WeekOfYear      1461
# Month           1461
# IsWeekend       1461
# IsHoliday       1461
# NUMBER_INT      1461
# temp_max        1461
# temp_min        1461
# humidity_max    1461
# dtype: int64 rows
# Validation set size: Date            360
# DayOfWeekNum    360
# WeekOfYear      360
# Month           360
# IsWeekend       360
# IsHoliday       360
# NUMBER_INT      360
# temp_max        360
# temp_min        360
# humidity_max    360
# dtype: int64 rows
# Training set date range: 2015-01-01 00:00:00 to 2018-12-31 00:00:00
# Validation set date range: 2019-01-01 00:00:00 to 2019-12-26 00:00:00

# %%
results = []

# %%
best_rf_model_base = RandomForestRegressor(
    n_estimators=20,
    max_depth=6,
    min_samples_split=16,
    random_state=9
)

best_rf_model_base.fit(X_train, y_train)

y_pred = best_rf_model_base.predict(X_val)

# Metrics 1y
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val, y_pred)
mape_val = mape(y_val, y_pred)
smape_val = smape(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
corr = np.corrcoef(y_val, y_pred)[0, 1]

results.append({
    'MSE': mse,
    'RMSE': rmse,
    'MAE': mae,
    'MAPE': mape_val,
    'sMAPE': smape_val,
    'R2': r2,
    'Correlation': corr
})

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_val.index, y_val.values, label='Actual', linewidth=2)
plt.plot(y_val.index, y_pred, label='Predicted (Best Model)', linewidth=2, linestyle='--')
plt.xlabel('Time')
plt.ylabel('NUMBER_INT')
plt.title(f'Actual vs Predicted Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
results
# Out:
# [{'MSE': 118.46528724070834,
#   'RMSE': 10.88417600191711,
#   'MAE': 8.106401203057157,
#   'MAPE': 15.438129557090782,
#   'sMAPE': 16.428265889465187,
#   'R2': 0.5044579535395584,
#   'Correlation': 0.7832618681004934}]

# %%
importances = best_rf_model_base.feature_importances_
features = X.columns
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(12,6))
plt.title('Feature Importances')
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), features[indices])
plt.tight_layout()
plt.show()

# %%
importances[indices]
# Out:
# array([0.41355776, 0.21510835, 0.19030288, 0.08203985, 0.04886889,
#        0.01772122, 0.01689043, 0.01551062])

# %% [markdown]
# # Pointwise Density + Local Fit

# %%
# Scaler

# No scaller needed for Gower distance

# scaler = MinMaxScaler()
#scaler = StandardScaler()
# X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
# X_val_scaled = pd.DataFrame(scaler.transform(X_val), columns=X_val.columns, index=X_val.index)

# %%
X_train.dtypes
# Out:
# DayOfWeekNum     object
# WeekOfYear       object
# Month            object
# IsWeekend        object
# IsHoliday        object
# temp_max        float64
# temp_min        float64
# humidity_max    float64
# dtype: object

# %%
train_distance_matrix = gower.gower_matrix(X_train)

# Get upper triangle of the symmetric matrix (excluding diagonal)
i_upper = np.triu_indices_from(train_distance_matrix, k=1)
pairwise_distances_train = train_distance_matrix[i_upper]


percentile_number = 0.5
selected_percentile = np.percentile(pairwise_distances_train, percentile_number)
count_below_percentile = np.sum(pairwise_distances_train <= selected_percentile)

# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(pairwise_distances_train, bins=50, edgecolor='black', alpha=0.75)
plt.axvline(selected_percentile, color='red', linestyle='--', label=f'{percentile_number} percentile = {selected_percentile:.3f}')
plt.text(selected_percentile + 0.02, plt.ylim()[1]*0.8,
         f'{count_below_percentile:,} pairs\n≤ {selected_percentile:.3f}',
         color='red', fontsize=12, bbox=dict(facecolor='white', edgecolor='red', boxstyle='round,pad=0.3'))

plt.xlabel("Gower Distance (training instances)")
plt.ylabel("Instance Count")
plt.title("Pairwise Gower Distances")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
within_threshold = (train_distance_matrix <= selected_percentile)

# Exclude self-comparison (on the diagonal)
np.fill_diagonal(within_threshold, False)

# Count neighbors within threshold for each instance
neighbors_within_threshold = np.sum(within_threshold, axis=1)

k_max = int(np.mean(neighbors_within_threshold))
k_max
# Out:
# 7

# %%
# Reliability 
def compute_density(distances_row, threshold, min_cluster_units):
    count = np.sum(distances_row <= threshold)
    return min(count, min_cluster_units) / min_cluster_units


def compute_data_agreement(distances_row, y_pred_new, y_train, min_cluster_units, tolerance, threshold):
    # Select neighbors within threshold
    candidate_indices = np.where(distances_row <= threshold)[0]
    count = len(candidate_indices)
    if count == 0:
        return 0.0

    # Sort by distance
    sorted_indices = candidate_indices[np.argsort(distances_row[candidate_indices])]
    selected_indices = sorted_indices[:min(count, min_cluster_units)]

    neighbor_targets = y_train.iloc[selected_indices]
    agreement_count = np.sum(np.abs(neighbor_targets - y_pred_new) < tolerance)

    return agreement_count / min(count, min_cluster_units)


def compute_ml_agreement(distances_row, y_pred_new, X_train, model, min_cluster_units, tolerance, threshold):
    candidate_indices = np.where(distances_row <= threshold)[0]
    count = len(candidate_indices)
    if count == 0:
        return 0.0

    sorted_indices = candidate_indices[np.argsort(distances_row[candidate_indices])]
    selected_indices = sorted_indices[:min(count, min_cluster_units)]

    X_neighbors_full = X_train.iloc[selected_indices]
    neighbor_preds = model.predict(X_neighbors_full)
    agreement_count = np.sum(np.abs(neighbor_preds - y_pred_new) < tolerance)

    return agreement_count / min(count, min_cluster_units)


def compute_reliability_score_fast(distances_row, y_pred_new, X_train, y_train, model, threshold, min_cluster_units, tolerance):
    density = compute_density(distances_row, threshold, min_cluster_units)
    data_agreement = compute_data_agreement(distances_row, y_pred_new, y_train, min_cluster_units, tolerance, threshold)
    ml_agreement = compute_ml_agreement(distances_row, y_pred_new, X_train, model, min_cluster_units, tolerance, threshold)
    print(f"Density: {density}, Data Agreement: {data_agreement}, ML Agreement: {ml_agreement} Reliability Score: {(density * data_agreement * ml_agreement)}")
    return density * data_agreement * ml_agreement
    #return data_agreement

# %%
# Setup
final_tolerance = 8
final_min_cluster_uni = 7
final_threshold = 0.152

# %%
val_to_train_distances = gower.gower_matrix(X_val, X_train)


reliability_scores = []

for i in range(len(X_val)):
    distances_row = val_to_train_distances[i]
    y_pred_new = y_pred[i]
    

    score = compute_reliability_score_fast(
        distances_row,
        y_pred_new,
        X_train,
        y_train,
        best_rf_model_base,
        threshold=final_threshold,
        min_cluster_units=final_min_cluster_uni,
        tolerance=final_tolerance
    )

    print(f"Instance {i} | Predicted: {y_pred_new} | Reliability: {score:.4f}")
    
    reliability_scores.append(score)

# Add reliability scores to df_val
df_val['Reliability'] = reliability_scores
# Out:
# Density: 0.42857142857142855, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 0 | Predicted: 36.437305208828825 | Reliability: 0.4286
# Density: 0.8571428571428571, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 1 | Predicted: 41.60728878263213 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 2 | Predicted: 38.70871120420453 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 3 | Predicted: 41.477146709664154 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 4 | Predicted: 24.049912752700028 | Reliability: 0.8571
# Density: 0.8571428571428571, Data Agreement: 0.8333333333333334, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 5 | Predicted: 20.952010876224154 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 6 | Predicted: 38.51286128044798 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 7 | Predicted: 39.79192508458241 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 0.8571428571428571 Reliability Score: 0.48979591836734687
# Instance 8 | Predicted: 41.52515456291468 | Reliability: 0.4898
# Density: 1.0, Data Agreement: 0.2857142857142857, ML Agreement: 1.0 Reliability Score: 0.2857142857142857
# Instance 9 | Predicted: 39.15856910767642 | Reliability: 0.2857
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 10 | Predicted: 38.24209875596437 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 11 | Predicted: 26.037168397618718 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 12 | Predicted: 20.48214354247095 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 13 | Predicted: 37.29723539154111 | Reliability: 0.5714
# Density: 0.8571428571428571, Data Agreement: 0.8333333333333334, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 14 | Predicted: 37.344941533163095 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 15 | Predicted: 37.31944866658889 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 16 | Predicted: 36.61244884714848 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 17 | Predicted: 38.44010406134739 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 18 | Predicted: 28.7034921839856 | Reliability: 0.7143
# Density: 0.5714285714285714, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 19 | Predicted: 19.871166083761715 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 20 | Predicted: 36.81996594173471 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 21 | Predicted: 38.15821132786381 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 22 | Predicted: 38.061542538433336 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 23 | Predicted: 34.71451041017953 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 24 | Predicted: 37.5526953582102 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 25 | Predicted: 26.05414661867302 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 26 | Predicted: 20.70885870231111 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 27 | Predicted: 37.11903227273286 | Reliability: 0.8571
# Density: 0.7142857142857143, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 28 | Predicted: 36.20728482511585 | Reliability: 0.7143
# Density: 0.7142857142857143, Data Agreement: 0.6, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 29 | Predicted: 35.730527233331074 | Reliability: 0.4286
# Density: 0.2857142857142857, Data Agreement: 0.0, ML Agreement: 1.0 Reliability Score: 0.0
# Instance 30 | Predicted: 35.75883789555965 | Reliability: 0.0000
# Density: 0.2857142857142857, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.2857142857142857
# Instance 31 | Predicted: 34.71451041017953 | Reliability: 0.2857
# Density: 0.42857142857142855, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.2857142857142857
# Instance 32 | Predicted: 27.679078362512957 | Reliability: 0.2857
# Density: 0.5714285714285714, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 33 | Predicted: 22.203065663509697 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 0.5714285714285714 Reliability Score: 0.32653061224489793
# Instance 34 | Predicted: 40.177060219717546 | Reliability: 0.3265
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 35 | Predicted: 39.61489257867224 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 36 | Predicted: 36.799373947505075 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 37 | Predicted: 41.25855857265498 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 38 | Predicted: 43.08140944325584 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 39 | Predicted: 22.9259840423806 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 40 | Predicted: 20.69700797120201 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 41 | Predicted: 39.58009801387284 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.2857142857142857, ML Agreement: 0.7142857142857143 Reliability Score: 0.20408163265306123
# Instance 42 | Predicted: 33.06417196027577 | Reliability: 0.2041
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 43 | Predicted: 42.30359800687338 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 44 | Predicted: 46.38229256446006 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 0.8571428571428571 Reliability Score: 0.6122448979591837
# Instance 45 | Predicted: 37.15820303311936 | Reliability: 0.6122
# Density: 0.7142857142857143, Data Agreement: 0.8, ML Agreement: 1.0 Reliability Score: 0.5714285714285715
# Instance 46 | Predicted: 26.829512835992176 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 47 | Predicted: 24.645768138837948 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 48 | Predicted: 41.400387810339076 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.2857142857142857, ML Agreement: 0.8571428571428571 Reliability Score: 0.24489795918367344
# Instance 49 | Predicted: 43.92488460290543 | Reliability: 0.2449
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 0.8571428571428571 Reliability Score: 0.36734693877551017
# Instance 50 | Predicted: 40.22197354572076 | Reliability: 0.3673
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 51 | Predicted: 45.62821362368757 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 52 | Predicted: 46.566042171773475 | Reliability: 0.4286
# Density: 0.8571428571428571, Data Agreement: 0.8333333333333334, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 53 | Predicted: 27.609624630630282 | Reliability: 0.7143
# Density: 0.8571428571428571, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 54 | Predicted: 25.65948401641358 | Reliability: 0.5714
# Density: 0.8571428571428571, Data Agreement: 0.3333333333333333, ML Agreement: 0.8333333333333334 Reliability Score: 0.23809523809523808
# Instance 55 | Predicted: 47.61775099045822 | Reliability: 0.2381
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 0.7142857142857143 Reliability Score: 0.30612244897959184
# Instance 56 | Predicted: 50.648960009309505 | Reliability: 0.3061
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 0.8571428571428571 Reliability Score: 0.36734693877551017
# Instance 57 | Predicted: 49.822891460922406 | Reliability: 0.3673
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 0.8571428571428571 Reliability Score: 0.7346938775510203
# Instance 58 | Predicted: 48.438496310424306 | Reliability: 0.7347
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 59 | Predicted: 52.86979013151722 | Reliability: 0.7143
# Density: 0.7142857142857143, Data Agreement: 0.4, ML Agreement: 1.0 Reliability Score: 0.28571428571428575
# Instance 60 | Predicted: 36.28447848120941 | Reliability: 0.2857
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 61 | Predicted: 31.245866088914756 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 0.8571428571428571 Reliability Score: 0.8571428571428571
# Instance 62 | Predicted: 50.600127792300526 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 0.8571428571428571 Reliability Score: 0.7346938775510203
# Instance 63 | Predicted: 50.27300360929399 | Reliability: 0.7347
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 64 | Predicted: 51.01901668118942 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 65 | Predicted: 50.69189249818288 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 66 | Predicted: 50.52060324697515 | Reliability: 0.5714
# Density: 0.5714285714285714, Data Agreement: 0.75, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 67 | Predicted: 33.632634821128526 | Reliability: 0.4286
# Density: 0.8571428571428571, Data Agreement: 0.8333333333333334, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 68 | Predicted: 32.44569164712847 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 69 | Predicted: 54.32769782927592 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 70 | Predicted: 56.39165391676143 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 71 | Predicted: 52.47605916484955 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 72 | Predicted: 51.96650559342097 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 73 | Predicted: 55.2986403946217 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 0.8571428571428571 Reliability Score: 0.6122448979591837
# Instance 74 | Predicted: 35.79296529986031 | Reliability: 0.6122
# Density: 0.8571428571428571, Data Agreement: 0.5, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 75 | Predicted: 37.37765831861487 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 0.8571428571428571 Reliability Score: 0.48979591836734687
# Instance 76 | Predicted: 55.84940495569687 | Reliability: 0.4898
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 77 | Predicted: 55.09093721376139 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 78 | Predicted: 55.09093721376139 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 79 | Predicted: 56.84892340931191 | Reliability: 0.4286
# Density: 0.5714285714285714, Data Agreement: 0.25, ML Agreement: 1.0 Reliability Score: 0.14285714285714285
# Instance 80 | Predicted: 56.17051281244992 | Reliability: 0.1429
# Density: 0.8571428571428571, Data Agreement: 0.8333333333333334, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 81 | Predicted: 37.81415762235935 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 82 | Predicted: 36.6414734316279 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.2857142857142857, ML Agreement: 1.0 Reliability Score: 0.2857142857142857
# Instance 83 | Predicted: 66.80548360689912 | Reliability: 0.2857
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 0.8571428571428571 Reliability Score: 0.36734693877551017
# Instance 84 | Predicted: 66.80548360689912 | Reliability: 0.3673
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 85 | Predicted: 66.80548360689912 | Reliability: 0.4286
# Instance 154 | Predicted: 66.55432670427912 | Reliability: 0.4286
# Density: 0.5714285714285714, Data Agreement: 0.75, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 155 | Predicted: 66.43266652801348 | Reliability: 0.4286
# Density: 0.5714285714285714, Data Agreement: 0.75, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 156 | Predicted: 65.76164785297526 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.2857142857142857, ML Agreement: 1.0 Reliability Score: 0.2857142857142857
# Instance 157 | Predicted: 63.24982448056951 | Reliability: 0.2857
# Density: 0.7142857142857143, Data Agreement: 0.8, ML Agreement: 1.0 Reliability Score: 0.5714285714285715
# Instance 158 | Predicted: 46.64716541122164 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 159 | Predicted: 39.99068771104619 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 160 | Predicted: 65.40685678913458 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 161 | Predicted: 65.9585169654002 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 162 | Predicted: 66.48574671302063 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 163 | Predicted: 66.45818456487176 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 164 | Predicted: 64.27287769166102 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 165 | Predicted: 48.779894659229306 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 166 | Predicted: 40.78225046408264 | Reliability: 0.8571
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 167 | Predicted: 64.87589384212897 | Reliability: 0.4286
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 168 | Predicted: 65.90640683224741 | Reliability: 0.5714
# Density: 0.8571428571428571, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 169 | Predicted: 65.95478376601503 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 170 | Predicted: 65.66538815720916 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 273 | Predicted: 45.664465810898314 | Reliability: 0.5714
# Density: 0.8571428571428571, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 274 | Predicted: 46.84732706680828 | Reliability: 0.5714
# Density: 0.5714285714285714, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 275 | Predicted: 46.3731305954755 | Reliability: 0.5714
# Density: 0.7142857142857143, Data Agreement: 0.8, ML Agreement: 1.0 Reliability Score: 0.5714285714285715
# Instance 276 | Predicted: 46.44823235749788 | Reliability: 0.5714
# Density: 0.7142857142857143, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 277 | Predicted: 30.20838459617601 | Reliability: 0.7143
# Density: 0.7142857142857143, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 278 | Predicted: 25.928092489231584 | Reliability: 0.7143
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 279 | Predicted: 44.768933611882105 | Reliability: 1.0000
# Density: 0.8571428571428571, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 280 | Predicted: 44.83974505854344 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 0.5714285714285714, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 281 | Predicted: 45.75298449589841 | Reliability: 0.5714
# Density: 1.0, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 1.0
# Instance 282 | Predicted: 45.62351160514301 | Reliability: 1.0000
# Density: 1.0, Data Agreement: 0.8571428571428571, ML Agreement: 1.0 Reliability Score: 0.8571428571428571
# Instance 283 | Predicted: 46.15756303016389 | Reliability: 0.8571
# Density: 0.14285714285714285, Data Agreement: 1.0, ML Agreement: 1.0 Reliability Score: 0.14285714285714285
# Instance 284 | Predicted: 31.383205897295788 | Reliability: 0.1429
# Density: 0.7142857142857143, Data Agreement: 0.4, ML Agreement: 1.0 Reliability Score: 0.28571428571428575
# Instance 285 | Predicted: 27.868322781968565 | Reliability: 0.2857
# Density: 0.7142857142857143, Data Agreement: 0.4, ML Agreement: 0.8 Reliability Score: 0.22857142857142862
# Instance 286 | Predicted: 44.59459439432485 | Reliability: 0.2286
# Density: 0.7142857142857143, Data Agreement: 0.4, ML Agreement: 1.0 Reliability Score: 0.28571428571428575
# Instance 287 | Predicted: 45.51654193354345 | Reliability: 0.2857
# Density: 1.0, Data Agreement: 0.42857142857142855, ML Agreement: 1.0 Reliability Score: 0.42857142857142855
# Instance 288 | Predicted: 45.75298449589841 | Reliability: 0.4286
# Density: 0.8571428571428571, Data Agreement: 0.6666666666666666, ML Agreement: 1.0 Reliability Score: 0.5714285714285714
# Instance 289 | Predicted: 45.42172705542222 | Reliability: 0.5714
# Density: 0.8571428571428571, Data Agreement: 0.16666666666666666, ML Agreement: 1.0 Reliability Score: 0.14285714285714285
# Instance 358 | Predicted: 32.27613698944508 | Reliability: 0.0952
# Density: 1.0, Data Agreement: 0.7142857142857143, ML Agreement: 1.0 Reliability Score: 0.7142857142857143
# Instance 359 | Predicted: 45.70788735246488 | Reliability: 0.7143

# %%
i = 0
distances_row = val_to_train_distances[i]
nearest_indices = np.argsort(distances_row)[:5]

print("Val instance:", X_val.iloc[i].to_dict())
print("Nearest train indices:", nearest_indices)
print("Corresponding distances:", distances_row[nearest_indices])
print("Nearest train samples:")
print(X_train.iloc[nearest_indices])
# Out:
# Val instance: {'DayOfWeekNum': 1, 'WeekOfYear': 1, 'Month': 1, 'IsWeekend': 0, 'IsHoliday': 1, 'temp_max': 27.9, 'temp_min': 19.2, 'humidity_max': 92.0}
# Nearest train indices: [ 369 1097 1096    0  733]
# Corresponding distances: [0.13718519 0.13842277 0.14511919 0.18031664 0.19870184]
# Nearest train samples:
#      DayOfWeekNum WeekOfYear Month IsWeekend IsHoliday  temp_max  temp_min  \
# 369             1          1     1         0         0      27.5      17.9
# 1097            1          1     1         0         0      29.8      19.4
# 1096            0          1     1         0         1      29.8      20.3
# 0               3          1     1         0         1      33.9      20.6
# 733             1          1     1         0         0      33.0      20.6
#
#       humidity_max
# 369           92.0
# 1097          92.0
# 1096          92.0
# 0             89.0
# 733           79.0

# %%
# Absolute prediction error
errors = np.abs(y_val.values - y_pred)

plt.figure(figsize=(12, 6))
plt.scatter(df_val['Reliability'], errors, alpha=0.6)
plt.xlabel("Reliability Score")
plt.ylabel("Absolute Error")
plt.title("Reliability Score vs. Absolute Prediction Error")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
tolerance = final_tolerance

df_plot = df_val.copy()
df_plot["y_true"] = y_val.values
df_plot["y_pred"] = y_pred
df_plot["abs_error"] = np.abs(df_plot["y_true"] - df_plot["y_pred"])

df_plot["correct"] = df_plot["abs_error"] <= tolerance

# Define reliability bins
bins = np.linspace(0, 1, 11)  # 0.0 to 1.0 in steps of 0.1
labels = [f"]{bins[i]:.2f}, {bins[i+1]:.2f}]" for i in range(len(bins)-1)]
df_plot["reliability_bin"] = pd.cut(df_plot["Reliability"], bins=bins, labels=labels, include_lowest=True)

# Group by reliability bin
grouped = df_plot.groupby("reliability_bin")
pop_count = grouped.size()
correct_count = grouped["correct"].sum()
error_rate = 1 - (correct_count / pop_count)

fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.bar(pop_count.index, pop_count.values, alpha=0.5, color='skyblue', label="Population Count")
ax1.set_ylabel("Population Count", color='black')
ax1.set_xlabel("Reliability Intervals")
ax1.tick_params(axis='x', rotation=45)

ax2 = ax1.twinx()
ax2.plot(error_rate.index, error_rate.values, marker='o', color='red', label="Error Rate")
ax2.set_ylabel("Error Rate")
ax2.set_ylim(0, 1.05)

plt.title(f"Population and Error Rate by Reliability Interval (Tolerance = ±{tolerance})")
fig.legend(loc="upper right", bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_8320/2153609289.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_plot.groupby("reliability_bin")
