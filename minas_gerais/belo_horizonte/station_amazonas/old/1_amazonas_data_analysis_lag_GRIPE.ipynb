# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data

# %%
df = pd.read_csv("df_final_bh_amazonas_GRIPE.csv")

# %%
df.head()
# Out:
#          Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0  2015-01-01       Thu             3          0      33.9      20.6
# 1  2015-01-02       Fri             4          0      32.9      21.0
# 2  2015-01-03       Sat             5          1      33.5      20.2
# 3  2015-01-04       Sun             6          1      30.6      22.2
# 4  2015-01-05       Mon             0          0      30.8      20.8
#
#    humidity_max  humidity_min  NUMBER_INT   CO  MP10    O3  MP2.5   SO2
# 0          89.0          32.0          20  0.0   NaN  68.0    NaN  82.0
# 1          87.0          38.0          17  0.0   NaN  79.0    NaN  83.0
# 2          83.0          38.0          11  0.0   NaN  44.0    NaN  83.0
# 3          81.0          43.0           9  0.0   NaN  49.0    NaN  82.0
# 4          79.0          36.0          19  0.0   NaN  59.0    NaN  82.0

# %%
df.count()
# Out:
# Date            1826
# DayOfWeek       1826
# DayOfWeekNum    1826
# IsWeekend       1826
# temp_max        1826
# temp_min        1826
# humidity_max    1826
# humidity_min    1826
# NUMBER_INT      1826
# CO              1581
# MP10            1457
# O3              1265
# MP2.5           1195
# SO2             1091
# dtype: int64

# %% [markdown]
# # LAG - CO

# %%
selected_cols_co = [
    'Date',
    'NUMBER_INT',
    'CO'
]

df_selected_co = df[selected_cols_co].copy()

# %%
df_selected_co.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# CO            1581
# dtype: int64

# %%
df_selected_co['CO_lag1'] = df_selected_co['CO'].shift(1)
df_selected_co['CO_lag2'] = df_selected_co['CO'].shift(2)
df_selected_co['CO_lag3'] = df_selected_co['CO'].shift(3)
df_selected_co['CO_lag4'] = df_selected_co['CO'].shift(4)
df_selected_co['CO_lag5'] = df_selected_co['CO'].shift(5)
df_selected_co['CO_lag6'] = df_selected_co['CO'].shift(6)
df_selected_co['CO_lag7'] = df_selected_co['CO'].shift(7)

# df_selected_co = df_selected_co.reset_index(drop=True)

# %%
# df_selected_co = df_selected_co.dropna()

# %%
df_selected_co.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# CO            1581
# CO_lag1       1581
# CO_lag2       1581
# CO_lag3       1581
# CO_lag4       1581
# CO_lag5       1581
# CO_lag6       1581
# CO_lag7       1581
# dtype: int64

# %%
correlation_matrix = df_selected_co.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - **SO2**

# %%
selected_cols_so2 = [
    'Date',
    'NUMBER_INT',
    'SO2'
]

df_selected_so2 = df[selected_cols_so2].copy()

# %%
df_selected_so2['SO2_lag1'] = df_selected_so2['SO2'].shift(1)
df_selected_so2['SO2_lag2'] = df_selected_so2['SO2'].shift(2)
df_selected_so2['SO2_lag3'] = df_selected_so2['SO2'].shift(3)
df_selected_so2['SO2_lag4'] = df_selected_so2['SO2'].shift(4)
df_selected_so2['SO2_lag5'] = df_selected_so2['SO2'].shift(5)
df_selected_so2['SO2_lag6'] = df_selected_so2['SO2'].shift(6)
df_selected_so2['SO2_lag7'] = df_selected_so2['SO2'].shift(7)

# %%
df_selected_so2.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# SO2           1091
# SO2_lag1      1091
# SO2_lag2      1091
# SO2_lag3      1091
# SO2_lag4      1091
# SO2_lag5      1091
# SO2_lag6      1091
# SO2_lag7      1091
# dtype: int64

# %%
correlation_matrix = df_selected_so2.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - **MP2.5**

# %%
selected_cols_mp25 = [
    'Date',
    'NUMBER_INT',
    'MP2.5'
]

df_selected_mp25 = df[selected_cols_mp25].copy()

df_selected_mp25['MP2.5_lag1'] = df_selected_mp25['MP2.5'].shift(1)
df_selected_mp25['MP2.5_lag2'] = df_selected_mp25['MP2.5'].shift(2)
df_selected_mp25['MP2.5_lag3'] = df_selected_mp25['MP2.5'].shift(3)
df_selected_mp25['MP2.5_lag4'] = df_selected_mp25['MP2.5'].shift(4)
df_selected_mp25['MP2.5_lag5'] = df_selected_mp25['MP2.5'].shift(5)
df_selected_mp25['MP2.5_lag6'] = df_selected_mp25['MP2.5'].shift(6)
df_selected_mp25['MP2.5_lag7'] = df_selected_mp25['MP2.5'].shift(7)

df_selected_mp25.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# MP2.5         1195
# MP2.5_lag1    1194
# MP2.5_lag2    1193
# MP2.5_lag3    1192
# MP2.5_lag4    1191
# MP2.5_lag5    1190
# MP2.5_lag6    1189
# MP2.5_lag7    1188
# dtype: int64

# %%
correlation_matrix = df_selected_mp25.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df_selected_mp25.head(25)
# Out:
#           Date  NUMBER_INT  MP2.5  MP2.5_lag1  MP2.5_lag2  MP2.5_lag3  \
# 0   2015-01-01          20    NaN         NaN         NaN         NaN
# 1   2015-01-02          17    NaN         NaN         NaN         NaN
# 2   2015-01-03          11    NaN         NaN         NaN         NaN
# 3   2015-01-04           9    NaN         NaN         NaN         NaN
# 4   2015-01-05          19    NaN         NaN         NaN         NaN
# 5   2015-01-06          12    NaN         NaN         NaN         NaN
# 6   2015-01-07          15    NaN         NaN         NaN         NaN
# 7   2015-01-08          16    NaN         NaN         NaN         NaN
# 8   2015-01-09           9    NaN         NaN         NaN         NaN
# 9   2015-01-10           7    NaN         NaN         NaN         NaN
# 10  2015-01-11          11    NaN         NaN         NaN         NaN
# 11  2015-01-12          15    NaN         NaN         NaN         NaN
# ...

# %%
df_selected_mp25.tail(25)
# Out:
#             Date  NUMBER_INT  MP2.5  MP2.5_lag1  MP2.5_lag2  MP2.5_lag3  \
# 1801  2019-12-07          15    8.0        10.0        10.0         3.0
# 1802  2019-12-08          14    NaN         8.0        10.0        10.0
# 1803  2019-12-09          13    5.0         NaN         8.0        10.0
# 1804  2019-12-10          16    8.0         5.0         NaN         8.0
# 1805  2019-12-11          18   11.0         8.0         5.0         NaN
# 1806  2019-12-12          18   10.0        11.0         8.0         5.0
# 1807  2019-12-13          13   10.0        10.0        11.0         8.0
# 1808  2019-12-14          17    5.0        10.0        10.0        11.0
# 1809  2019-12-15          10    3.0         5.0        10.0        10.0
# 1810  2019-12-16          16    3.0         3.0         5.0        10.0
# 1811  2019-12-17          18    6.0         3.0         3.0         5.0
# 1812  2019-12-18          13    6.0         6.0         3.0         3.0
# ...

# %% [markdown]
# # LAG - O3

# %%
selected_cols_o3 = [
    'Date',
    'NUMBER_INT',
    'O3'
]

df_selected_o3 = df[selected_cols_o3].copy()

df_selected_o3['O3_lag1'] = df_selected_o3['O3'].shift(1)
df_selected_o3['O3_lag2'] = df_selected_o3['O3'].shift(2)
df_selected_o3['O3_lag3'] = df_selected_o3['O3'].shift(3)
df_selected_o3['O3_lag4'] = df_selected_o3['O3'].shift(4)
df_selected_o3['O3_lag5'] = df_selected_o3['O3'].shift(5)
df_selected_o3['O3_lag6'] = df_selected_o3['O3'].shift(6)
df_selected_o3['O3_lag7'] = df_selected_o3['O3'].shift(7)

df_selected_o3.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# O3            1265
# O3_lag1       1265
# O3_lag2       1265
# O3_lag3       1265
# O3_lag4       1265
# O3_lag5       1265
# O3_lag6       1265
# O3_lag7       1265
# dtype: int64

# %%
correlation_matrix = df_selected_o3.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - MP10

# %%
selected_cols_mp10 = [
    'Date',
    'NUMBER_INT',
    'MP10'
]

df_selected_mp10 = df[selected_cols_mp10].copy()

df_selected_mp10['MP10_lag1'] = df_selected_mp10['MP10'].shift(1)
df_selected_mp10['MP10_lag2'] = df_selected_mp10['MP10'].shift(2)
df_selected_mp10['MP10_lag3'] = df_selected_mp10['MP10'].shift(3)
df_selected_mp10['MP10_lag4'] = df_selected_mp10['MP10'].shift(4)
df_selected_mp10['MP10_lag5'] = df_selected_mp10['MP10'].shift(5)
df_selected_mp10['MP10_lag6'] = df_selected_mp10['MP10'].shift(6)
df_selected_mp10['MP10_lag7'] = df_selected_mp10['MP10'].shift(7)

df_selected_mp10.count()
# Out:
# Date          1826
# NUMBER_INT    1826
# MP10          1457
# MP10_lag1     1456
# MP10_lag2     1455
# MP10_lag3     1454
# MP10_lag4     1453
# MP10_lag5     1452
# MP10_lag6     1451
# MP10_lag7     1450
# dtype: int64

# %%
correlation_matrix = df_selected_mp10.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - Temp

# %%
selected_cols_temp = [
    'Date',
    'NUMBER_INT',
    'temp_max',
    'temp_min'
]

df_selected_temp = df[selected_cols_temp].copy()

df_selected_temp['temp_max_lag1'] = df_selected_temp['temp_max'].shift(1)
df_selected_temp['temp_max_lag2'] = df_selected_temp['temp_max'].shift(2)
df_selected_temp['temp_max_lag3'] = df_selected_temp['temp_max'].shift(3)
df_selected_temp['temp_max_lag4'] = df_selected_temp['temp_max'].shift(4)
df_selected_temp['temp_max_lag5'] = df_selected_temp['temp_max'].shift(5)
df_selected_temp['temp_max_lag6'] = df_selected_temp['temp_max'].shift(6)
df_selected_temp['temp_max_lag7'] = df_selected_temp['temp_max'].shift(7)

df_selected_temp['temp_min_lag1'] = df_selected_temp['temp_min'].shift(1)
df_selected_temp['temp_min_lag2'] = df_selected_temp['temp_min'].shift(2)
df_selected_temp['temp_min_lag3'] = df_selected_temp['temp_min'].shift(3)
df_selected_temp['temp_min_lag4'] = df_selected_temp['temp_min'].shift(4)
df_selected_temp['temp_min_lag5'] = df_selected_temp['temp_min'].shift(5)
df_selected_temp['temp_min_lag6'] = df_selected_temp['temp_min'].shift(6)
df_selected_temp['temp_min_lag7'] = df_selected_temp['temp_min'].shift(7)

df_selected_temp.count()
# Out:
# Date             1826
# NUMBER_INT       1826
# temp_max         1826
# temp_min         1826
# temp_max_lag1    1825
# temp_max_lag2    1824
# temp_max_lag3    1823
# temp_max_lag4    1822
# temp_max_lag5    1821
# temp_max_lag6    1820
# temp_max_lag7    1819
# temp_min_lag1    1825
# temp_min_lag2    1824
# temp_min_lag3    1823
# temp_min_lag4    1822
# temp_min_lag5    1821
# temp_min_lag6    1820
# temp_min_lag7    1819
# dtype: int64

# %%
correlation_matrix = df_selected_temp.select_dtypes(include='number').corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # LAG - Humidity

# %%
selected_cols_humi = [
    'Date',
    'NUMBER_INT',
    'humidity_max',
    'humidity_min'
]

df_selected_humi = df[selected_cols_humi].copy()

df_selected_humi['humidity_max_lag1'] = df_selected_humi['humidity_max'].shift(1)
df_selected_humi['humidity_max_lag2'] = df_selected_humi['humidity_max'].shift(2)
df_selected_humi['humidity_max_lag3'] = df_selected_humi['humidity_max'].shift(3)
df_selected_humi['humidity_max_lag4'] = df_selected_humi['humidity_max'].shift(4)
df_selected_humi['humidity_max_lag5'] = df_selected_humi['humidity_max'].shift(5)
df_selected_humi['humidity_max_lag6'] = df_selected_humi['humidity_max'].shift(6)
df_selected_humi['humidity_max_lag7'] = df_selected_humi['humidity_max'].shift(7)

df_selected_humi['humidity_min_lag1'] = df_selected_humi['humidity_min'].shift(1)
df_selected_humi['humidity_min_lag2'] = df_selected_humi['humidity_min'].shift(2)
df_selected_humi['humidity_min_lag3'] = df_selected_humi['humidity_min'].shift(3)
df_selected_humi['humidity_min_lag4'] = df_selected_humi['humidity_min'].shift(4)
df_selected_humi['humidity_min_lag5'] = df_selected_humi['humidity_min'].shift(5)
df_selected_humi['humidity_min_lag6'] = df_selected_humi['humidity_min'].shift(6)
df_selected_humi['humidity_min_lag7'] = df_selected_humi['humidity_min'].shift(7)

df_selected_humi.count()
# Out:
# Date                 1826
# NUMBER_INT           1826
# humidity_max         1826
# humidity_min         1826
# humidity_max_lag1    1825
# humidity_max_lag2    1824
# humidity_max_lag3    1823
# humidity_max_lag4    1822
# humidity_max_lag5    1821
# humidity_max_lag6    1820
# humidity_max_lag7    1819
# humidity_min_lag1    1825
# humidity_min_lag2    1824
# humidity_min_lag3    1823
# humidity_min_lag4    1822
# humidity_min_lag5    1821
# humidity_min_lag6    1820
# humidity_min_lag7    1819
# dtype: int64

# %%
correlation_matrix = df_selected_humi.select_dtypes(include='number').corr()
plt.figure(figsize=(18, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
