# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("df_final_bh_amazonas.csv")

# %%
df.head()
# Out:
#          Date DayOfWeek  DayOfWeekNum  WeekOfYear  Month  IsWeekend  \
# 0  2015-01-01       Thu             3           1      1          0
# 1  2015-01-02       Fri             4           1      1          0
# 2  2015-01-03       Sat             5           1      1          1
# 3  2015-01-04       Sun             6           1      1          1
# 4  2015-01-05       Mon             0           2      1          0
#
#    IsHoliday  IsDayAfterHoliday  temp_max  temp_min  temp_mean  humidity_max  \
# 0          1                  0      33.9      20.6  25.912500          89.0
# 1          0                  1      32.9      21.0  26.050000          87.0
# 2          0                  0      33.5      20.2  26.683333          83.0
# 3          0                  0      30.6      22.2  25.641667          81.0
# 4          0                  0      30.8      20.8  25.520833          79.0
#
#    humidity_min  NUMBER_INT   CO  MP10    O3  MP2.5   SO2
# ...

# %%
df.tail()
# Out:
#             Date DayOfWeek  DayOfWeekNum  WeekOfYear  Month  IsWeekend  \
# 1821  2019-12-27       Fri             4          52     12          0
# 1822  2019-12-28       Sat             5          52     12          1
# 1823  2019-12-29       Sun             6          52     12          1
# 1824  2019-12-30       Mon             0           1     12          0
# 1825  2019-12-31       Tue             1           1     12          0
#
#       IsHoliday  IsDayAfterHoliday  temp_max  temp_min  temp_mean  \
# 1821          0                  0      29.1      19.9  24.016667
# 1822          0                  0      28.6      19.7  23.245833
# 1823          0                  0      29.4      18.8  22.333333
# 1824          0                  0      29.3      18.1  22.958333
# 1825          0                  0      29.9      18.8  24.045833
#
#       humidity_max  humidity_min  NUMBER_INT  CO  MP10  O3  MP2.5  SO2
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['MonthName'] = df['Date'].dt.month_name().str[:3]
df['Holiday_Label'] = df['IsHoliday'].map({0: 'Non-Holiday', 1: 'Holiday'})

# %%
df.head()
# Out:
#         Date DayOfWeek  DayOfWeekNum  WeekOfYear  Month  IsWeekend  IsHoliday  \
# 0 2015-01-01       Thu             3           1      1          0          1
# 1 2015-01-02       Fri             4           1      1          0          0
# 2 2015-01-03       Sat             5           1      1          1          0
# 3 2015-01-04       Sun             6           1      1          1          0
# 4 2015-01-05       Mon             0           2      1          0          0
#
#    IsDayAfterHoliday  temp_max  temp_min  ...  humidity_min  NUMBER_INT   CO  \
# 0                  0      33.9      20.6  ...          32.0          30  0.0
# 1                  1      32.9      21.0  ...          38.0          43  0.0
# 2                  0      33.5      20.2  ...          38.0          23  0.0
# 3                  0      30.6      22.2  ...          43.0          20  0.0
# 4                  0      30.8      20.8  ...          36.0          51  0.0
#
# ...

# %% [markdown]
# ## Stats

# %%
df.dtypes
# Out:
# Date                 datetime64[ns]
# DayOfWeek                    object
# DayOfWeekNum                  int64
# WeekOfYear                    int64
# Month                         int64
# IsWeekend                     int64
# IsHoliday                     int64
# IsDayAfterHoliday             int64
# temp_max                    float64
# temp_min                    float64
# temp_mean                   float64
# humidity_max                float64
# humidity_min                float64
# NUMBER_INT                    int64
# CO                          float64
# MP10                        float64
# O3                          float64
# MP2.5                       float64
# SO2                         float64
# Year                          int32
# MonthName                    object
# Holiday_Label                object
# dtype: object

# %%
df.count()
# Out:
# Date                 1826
# DayOfWeek            1826
# DayOfWeekNum         1826
# WeekOfYear           1826
# Month                1826
# IsWeekend            1826
# IsHoliday            1826
# IsDayAfterHoliday    1826
# temp_max             1826
# temp_min             1826
# temp_mean            1826
# humidity_max         1826
# humidity_min         1826
# NUMBER_INT           1826
# CO                   1581
# MP10                 1457
# O3                   1265
# MP2.5                1195
# SO2                  1091
# Year                 1826
# MonthName            1826
# Holiday_Label        1826
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date                   0
# DayOfWeek              0
# DayOfWeekNum           0
# WeekOfYear             0
# Month                  0
# IsWeekend              0
# IsHoliday              0
# IsDayAfterHoliday      0
# temp_max               0
# temp_min               0
# temp_mean              0
# humidity_max           0
# humidity_min           0
# NUMBER_INT             0
# CO                   245
# MP10                 369
# O3                   561
# MP2.5                631
# SO2                  735
# Year                   0
# MonthName              0
# Holiday_Label          0
# dtype: int64

# %%
df.describe().T
# Out:
#                     count                 mean                  min  \
# Date                 1826  2017-07-01 12:00:00  2015-01-01 00:00:00
# DayOfWeekNum       1826.0             3.000548                  0.0
# WeekOfYear         1826.0            26.615553                  1.0
# Month              1826.0             6.523549                  1.0
# IsWeekend          1826.0             0.285871                  0.0
# IsHoliday          1826.0             0.024644                  0.0
# IsDayAfterHoliday  1826.0             0.024644                  0.0
# temp_max           1826.0            28.314513                 17.8
# temp_min           1826.0            17.791347                  7.3
# temp_mean          1826.0            22.276965               13.625
# humidity_max       1826.0            82.264513                 42.0
# humidity_min       1826.0            40.261227                 10.0
# NUMBER_INT         1826.0            47.780394                 11.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='DayOfWeek', y='NUMBER_INT', data=df, order=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.ylabel('Admissions')
plt.xlabel('')
plt.title('Admissions by Day of the Week')
plt.show()

# %%
df.groupby('DayOfWeek')['NUMBER_INT'].describe().loc[['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']]
# Out:
#            count       mean        std   min    25%   50%    75%   max
# DayOfWeek
# Mon        261.0  53.042146  14.402262  19.0  42.00  51.0  64.00  92.0
# Tue        261.0  51.839080  14.085623  12.0  42.00  50.0  62.00  94.0
# Wed        260.0  54.246154  14.208357  25.0  43.75  52.0  64.25  91.0
# Thu        261.0  54.076628  13.565860  24.0  45.00  54.0  64.00  91.0
# Fri        261.0  51.517241  12.791099  26.0  41.00  50.0  61.00  83.0
# Sat        261.0  37.915709  12.088479  13.0  28.00  36.0  45.00  78.0
# Sun        261.0  31.850575  11.048002  11.0  23.00  30.0  39.00  69.0

# %%
plt.figure(figsize=(12, 6))
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
sns.boxplot(x='MonthName', y='NUMBER_INT', data=df, order=month_order)
plt.ylabel('Admissions')
plt.xlabel('')
plt.title('Admissions by Month')
plt.show()

# %%
df.groupby('MonthName')['NUMBER_INT'].describe().loc[['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
# Out:
#            count       mean        std   min    25%   50%   75%   max
# MonthName
# Jan        155.0  35.012903   9.331546  14.0  29.00  36.0  42.0  53.0
# Feb        141.0  38.375887  13.294219  11.0  29.00  39.0  47.0  83.0
# Mar        155.0  51.580645  14.302788  22.0  42.00  51.0  60.0  91.0
# Apr        150.0  60.253333  14.146495  26.0  50.25  61.0  70.0  89.0
# May        155.0  62.483871  13.931817  22.0  54.00  64.0  72.5  91.0
# Jun        150.0  59.260000  13.325774  29.0  49.25  61.5  69.0  94.0
# Jul        155.0  53.354839  14.429741  20.0  44.50  54.0  63.0  92.0
# Aug        155.0  46.651613  12.876332  17.0  36.50  48.0  55.0  81.0
# Sep        150.0  42.480000  11.885200  14.0  35.00  43.0  51.0  77.0
# Oct        155.0  40.277419  11.553116  17.0  31.00  41.0  48.5  76.0
# Nov        150.0  39.980000  11.835262  13.0  32.00  39.0  47.0  77.0
# Dec        155.0  43.154839  12.234793  13.0  34.00  43.0  50.0  72.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='WeekOfYear', y='NUMBER_INT', data=df)
plt.ylabel('Admissions')
plt.xlabel('')
plt.title('Admissions by Week of the Year')
plt.show()

# %%
df.groupby('WeekOfYear')['NUMBER_INT'].describe()
# Out:
#             count       mean        std   min    25%   50%   75%   max
# WeekOfYear
# 1            34.0  35.500000   9.664838  17.0  29.25  35.0  43.0  61.0
# 2            35.0  34.400000  10.047534  17.0  29.00  34.0  39.0  53.0
# 3            35.0  34.600000   9.321701  16.0  29.50  36.0  41.5  51.0
# 4            35.0  35.742857   9.795986  14.0  29.50  37.0  43.5  50.0
# 5            35.0  34.914286  11.810692  16.0  27.00  32.0  42.0  64.0
# 6            35.0  32.942857  10.876155  11.0  26.50  35.0  41.5  52.0
# 7            35.0  38.685714  11.485980  12.0  33.50  40.0  45.0  66.0
# 8            35.0  41.342857  12.109653  18.0  30.00  42.0  51.0  63.0
# 9            35.0  48.714286  14.763969  26.0  40.00  47.0  56.5  83.0
# 10           35.0  45.028571  10.542591  22.0  38.00  45.0  51.0  69.0
# 11           35.0  49.628571  12.461908  25.0  39.00  50.0  59.5  72.0
# 12           35.0  51.857143  13.949790  26.0  43.00  50.0  61.0  83.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Year', y='NUMBER_INT', data=df)
plt.ylabel('Admissions')
plt.xlabel('')
plt.title('Admissions by Year')
plt.show()

# %%
df.groupby('Year')['NUMBER_INT'].describe().loc[[2015, 2016, 2017, 2018, 2019]]
# Out:
#       count       mean        std   min   25%   50%   75%   max
# Year
# 2015  365.0  46.764384  17.224578  13.0  35.0  44.0  56.0  94.0
# 2016  366.0  45.434426  15.502711  11.0  34.0  44.0  55.0  89.0
# 2017  365.0  45.071233  14.001192  13.0  35.0  44.0  54.0  91.0
# 2018  365.0  49.682192  14.776088  12.0  40.0  50.0  61.0  88.0
# 2019  365.0  51.956164  15.427542  13.0  40.0  50.0  64.0  92.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Holiday_Label', y='NUMBER_INT', data=df)
plt.ylabel('Admissions')
plt.title('Admissions: Holiday vs Non-Holiday')
plt.show()

# %%
df.groupby('Holiday_Label')['NUMBER_INT'].describe()
# Out:
#                 count       mean        std   min   25%   50%   75%   max
# Holiday_Label
# Holiday          45.0  40.222222  15.472687  23.0  29.0  35.0  50.0  91.0
# Non-Holiday    1781.0  47.971364  15.592521  11.0  37.0  47.0  59.0  94.0

# %% [markdown]
# ## Keynotes
#
# - series with two seasonal patterns, weekly and annual (seasonal periods of 7 and 365.25)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['NUMBER_INT'], bins=20)
plt.title('Distribution of Admissions')
plt.xlabel('Number of Admissions')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp_max', y='NUMBER_INT', data=df)
plt.title('Temperature (Max) vs Admissions')
plt.xlabel('Max Temperature (°C)')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp_min', y='NUMBER_INT', data=df)
plt.title('Temperature (Min) vs Admissions')
plt.xlabel('Min Temperature (°C)')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
selected_columns = [
    'DayOfWeekNum', 'IsWeekend',
    'WeekOfYear', 'Month', 'IsHoliday', 'IsDayAfterHoliday',
    'temp_max', 'temp_min', 'temp_mean',
    'humidity_max', 'humidity_min', 'NUMBER_INT', 
    'CO', 'MP10', 'O3', 'MP2.5', 'SO2'
]



df_selected_num = df[selected_columns]

correlation_matrix = df_selected_num.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['temp_min_lag1'] = df['temp_min'].shift(1)
df['temp_min_lag2'] = df['temp_min'].shift(2)
df['temp_min_lag3'] = df['temp_min'].shift(3)

df['humidity_max_lag1'] = df['humidity_max'].shift(1)
df['humidity_max_lag2'] = df['humidity_max'].shift(2)
df['humidity_max_lag3'] = df['humidity_max'].shift(3)

# %%
selected_columns_lag = [
    'NUMBER_INT',
    'temp_min', 'temp_min_lag1',
    'temp_min_lag2', 'temp_min_lag3',
    'humidity_max', 'humidity_max_lag1',
    'humidity_max_lag2', 'humidity_max_lag3'
]



df_selected_num2 = df[selected_columns_lag]

correlation_matrix = df_selected_num2.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df_selected_num.corr()['NUMBER_INT'].sort_values(ascending=False)
# Out:
# NUMBER_INT           1.000000
# MP10                 0.206634
# CO                   0.184340
# SO2                  0.178660
# MP2.5                0.155315
# humidity_max         0.119767
# humidity_min         0.035697
# IsDayAfterHoliday   -0.023986
# IsHoliday           -0.076879
# Month               -0.094141
# WeekOfYear          -0.095635
# O3                  -0.166449
# temp_max            -0.223986
# temp_mean           -0.265720
# temp_min            -0.288701
# DayOfWeekNum        -0.430371
# IsWeekend           -0.522166
# Name: NUMBER_INT, dtype: float64

# %%
weekend_vs_weekday = df.groupby('IsWeekend')['NUMBER_INT'].mean()
plt.bar(['Weekday', 'Weekend'], weekend_vs_weekday)
plt.title('Average Admissions: Weekday vs Weekend')
plt.ylabel('Average Admissions')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['NUMBER_INT'])
plt.title('Boxplot - Number of Admissions')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='MP10', y='NUMBER_INT', data=df, alpha=0.5)
plt.title('Admissions vs PM10 Levels')
plt.xlabel('PM10 Levels')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp_min', y='NUMBER_INT', data=df, alpha=0.5, color='orange')
plt.title('Admissions vs Minimum Temperature')
plt.xlabel('Minimum Temperature (°C)')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(25, 8))

df_copy = df.copy()

df_copy['Date'] = pd.to_datetime(df_copy['Date'], format='%Y%m%d')

features_plot = [
    'temp_max', 'temp_min', 'NUMBER_INT',
    'CO', 'MP10', 'O3', 'MP2.5', 'SO2'
]



for feature in features_plot:
    plt.plot(df_copy['Date'], 
             df_copy[feature], 
             label=feature)

plt.title('Trends of Key Features Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 8))

features_plot_with_day = [
    'DayOfWeekNum',
    'temp_max', 
    'temp_min', 
    'NUMBER_INT'
]



for feature in features_plot_with_day:
    plt.plot(df_copy['Date'], 
             df_copy[feature], 
             label=feature)

plt.title('Trends of Key Features Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
selected_columns_C = [
    'IsWeekend',
    'IsHoliday', 
    'IsDayAfterHoliday',
    'temp_max', 
    'temp_min',
    'humidity_max',
    'humidity_min', 
    'MP10',
    'O3',
    'SO2',
    'NUMBER_INT'
]

column_rename_map = {
    'IsWeekend': 'Is Weekend',
    'IsHoliday': 'Is Holiday',
    'IsDayAfterHoliday': 'IS Day After Holiday',
    'temp_max': 'Max Temperature',
    'temp_min': 'Min Temperature',
    'humidity_max': 'Max Humidity',
    'humidity_min': 'Min Humidity',
    'NUMBER_INT': 'Admissions',
}

df_selected_num = df[selected_columns_C].rename(columns=column_rename_map)

correlation_matrix = df_selected_num.corr()

# Mask the upper triangle (keep lower triangle + diagonal)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool), k=1)


plt.figure(figsize=(16, 8))
sns.heatmap(
    correlation_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap='coolwarm', # 'RdBu_r'
    vmin=-1, vmax=1, # intensity range
    cbar_kws={"shrink": 0.8}
)
plt.title('Correlation Heatmap')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
