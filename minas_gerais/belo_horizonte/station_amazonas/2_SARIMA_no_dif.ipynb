# %% [markdown]
# For SARIMAX:
#   - Check for insignificant regressors (high p-values).
#   - Check for multicollinearity (via Variance Inflation Factor – VIF).
#   - Compare models with/without certain variables using AIC/BIC.
#
# ACF vs STL:
#
# | ACF (Autocorrelation Function)                   | STL (Seasonal-Trend decomposition using Loess)           |
# | ------------------------------------------------ | -------------------------------------------------------- |
# | Correlation of the series with its own past lags | Decomposes the series into trend, seasonality, residuals |
# | Correlation values for lags                      | Separate time series: trend, seasonal, residual          |
# | Identify autocorrelation and seasonality lags (model lags)    | Visualize and quantify seasonal and trend components     |
# | Bar plot of correlations (ACF/PACF plots)        | Time series line plots of components                     |
# | Peaks at lags = recurring cycles                 | Direct view of what the trend and seasonality look like  |
#
#
# # ARIMA vs SARIMA vs SARIMAX
#
# ## ARIMA
#
# Non-seasonal patterns in your time series. (p, d, q):
#   - p: AR (AutoRegressive)	- How many past values (lags) the model uses to predict the current value.
#   - d: Differencing - Number of times to difference the series to remove trend and make it stationary (statistical properties do not change over time: Constant mean, Constant variance, Constant autocorrelation structure)
#   - q: MA (Moving Average)	- How many past forecast errors (residuals) the model uses
#
#
# ## SARIMA: Seasonal ARIMA
#
# Add seasonal patterns (e.g., weekly or annual cycles) on top of ARIMA. seasonal_order=(P, D, Q, s):
#   - P: Seasonal AR	- how many seasonal lags to include ("Admissions today ≈ a × Admissions 7 days ago")
#   - D: Seasonal differencing - How many times to subtract seasonally (e.g., subtract value from 7 days ago)
#   - Q: Seasonal MA - Use errors from prior seasonal lags to correct predictions
#   - s: 	Seasonal period - 	The length of the seasonal cycle (e.g., s=7 for weekly data)
#
# ## SARIMA + exogenous variables
#
# xog=X -> optional DataFrame of exogenous features
#
#
# # Links
# - https://www.statsmodels.org/dev/examples/notebooks/generated/mstl_decomposition.html
# - https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html
# - https://medium.com/data-science/time-series-forecasting-using-auto-arima-in-python-bb83e49210c

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import seaborn as sns


from statsmodels.tsa.seasonal import STL
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def smape(y_true, y_pred):
    return 100 / len(y_true) * np.sum(
        2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred))
    )

# %%
df = pd.read_csv("df_final_bh_amazonas.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df.head(5)
# Out:
#            DayOfWeek  DayOfWeekNum  WeekOfYear  Month  IsWeekend  IsHoliday  \
# Date
# 2015-01-01       Thu             3           1      1          0          1
# 2015-01-02       Fri             4           1      1          0          0
# 2015-01-03       Sat             5           1      1          1          0
# 2015-01-04       Sun             6           1      1          1          0
# 2015-01-05       Mon             0           2      1          0          0
#
#             IsDayAfterHoliday  temp_max  temp_min  temp_mean  humidity_max  \
# Date
# 2015-01-01                  0      33.9      20.6  25.912500          89.0
# 2015-01-02                  1      32.9      21.0  26.050000          87.0
# 2015-01-03                  0      33.5      20.2  26.683333          83.0
# 2015-01-04                  0      30.6      22.2  25.641667          81.0
# 2015-01-05                  0      30.8      20.8  25.520833          79.0
#
#             humidity_min  NUMBER_INT   CO  MP10    O3  MP2.5   SO2
# Date
# 2015-01-01          32.0          30  0.0   NaN  68.0    NaN  82.0
# 2015-01-02          38.0          43  0.0   NaN  79.0    NaN  83.0
# 2015-01-03          38.0          23  0.0   NaN  44.0    NaN  83.0
# 2015-01-04          43.0          20  0.0   NaN  49.0    NaN  82.0
# 2015-01-05          36.0          51  0.0   NaN  59.0    NaN  82.0

# %%
# Time split: train = first 4 years, test = 5th year
min_year = df.index.year.min()
train_mask = df.index.year < (min_year + 4)
val_mask = df.index.year == (min_year + 4)

y_train = df.loc[train_mask, 'NUMBER_INT']

# Remove last 5 days from validation
y_val = df.loc[val_mask, 'NUMBER_INT'][:-5]

y_train.count()
# Out:
# 1461

# %% [markdown]
# ## ACF/PACF ADF
#
# Augmented Dickey-Fuller test. Statistical test used to determine if a time series is stationary (i.e., its properties don't change over time - avg, variance, covariance).

# %%
y_train_diff = y_train.diff().dropna()

adf_original = adfuller(y_train)
adf_diff = adfuller(y_train_diff)

print("ADF Test (Original Series)")
print(f"Test Statistic: {adf_original[0]:.4f}")
print(f"p-value: {adf_original[1]:.4f}")
print("Stationary" if adf_original[1] < 0.05 else "Not Stationary")
# Out:
# ADF Test (Original Series)
# Test Statistic: -2.7452
# p-value: 0.0665
# Not Stationary

# %%
print("\nADF Test (First-Differenced Series)")
print(f"Test Statistic: {adf_diff[0]:.4f}")
print(f"p-value: {adf_diff[1]:.4f}")
print("Stationary" if adf_diff[1] < 0.05 else " Not Stationary")
# Out:
# ADF Test (First-Differenced Series)
# Test Statistic: -8.9545
# p-value: 0.0000
# Stationary

# %%
# Plot ACF & PACF ---
fig, axes = plt.subplots(2, 2, figsize=(14, 8))

plot_acf(y_train, ax=axes[0, 0], lags=40, title='ACF - Original Series')
plot_pacf(y_train, ax=axes[0, 1], lags=40, title='PACF - Original Series')

plot_acf(y_train_diff, ax=axes[1, 0], lags=40, title='ACF - Differenced Series')
plot_pacf(y_train_diff, ax=axes[1, 1], lags=40, title='PACF - Differenced Series')

plt.show()

# %% [markdown]
# Based on visual inspection of ACF and PACF plots, along with ADF test results ( need for first differencing). The ARIMA model space was defined with non-seasonal orders (p, d, q) up to (...) and seasonal orders (P, D, Q) up to (...), across multiple seasonal periods.

# %%
import warnings
warnings.filterwarnings("ignore", message="'force_all_finite' was renamed")

start_time = time.time()

model = auto_arima(
    y_train,
    seasonal=True,
    m=7,
    start_p=0, max_p=15,
    start_q=0, max_q=15,
    d=0,
    start_P=0, max_P=2,
    start_Q=0, max_Q=2,
    max_D=1,
    stepwise=False, # Exhaustive search
    trace=True,
    # suppress_warnings=True,
    # error_action="ignore"
)

end_time = time.time()
elapsed = end_time - start_time
print(f"\nTraining time: {elapsed:.2f} seconds")
# Out:
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=12160.287, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,1)[7] intercept   : AIC=11604.278, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,2)[7] intercept   : AIC=11312.627, Time=1.14 sec
#  ARIMA(0,0,0)(1,0,0)[7] intercept   : AIC=11058.362, Time=0.65 sec
#  ARIMA(0,0,0)(1,0,1)[7] intercept   : AIC=10802.936, Time=1.25 sec
#  ARIMA(0,0,0)(1,0,2)[7] intercept   : AIC=10825.672, Time=2.37 sec
#  ARIMA(0,0,0)(2,0,0)[7] intercept   : AIC=10863.376, Time=2.57 sec
#  ARIMA(0,0,0)(2,0,1)[7] intercept   : AIC=inf, Time=3.82 sec
#  ARIMA(0,0,0)(2,0,2)[7] intercept   : AIC=10803.110, Time=3.60 sec
#  ARIMA(0,0,1)(0,0,0)[7] intercept   : AIC=11751.668, Time=0.20 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=11392.777, Time=0.66 sec
#  ARIMA(0,0,1)(0,0,2)[7] intercept   : AIC=11190.999, Time=0.84 sec
#  ARIMA(0,0,1)(1,0,0)[7] intercept   : AIC=11022.430, Time=0.65 sec
#  ARIMA(0,0,1)(1,0,1)[7] intercept   : AIC=10757.005, Time=3.32 sec
#  ARIMA(0,0,1)(1,0,2)[7] intercept   : AIC=10799.041, Time=3.64 sec
#  ARIMA(0,0,1)(2,0,0)[7] intercept   : AIC=10829.670, Time=4.04 sec
#  ARIMA(0,0,1)(2,0,1)[7] intercept   : AIC=10777.669, Time=3.95 sec
#  ARIMA(0,0,1)(2,0,2)[7] intercept   : AIC=11900.546, Time=2.48 sec
#  ARIMA(0,0,2)(0,0,0)[7] intercept   : AIC=11696.134, Time=0.38 sec
#  ARIMA(0,0,2)(0,0,1)[7] intercept   : AIC=11372.112, Time=0.92 sec
#  ARIMA(0,0,2)(0,0,2)[7] intercept   : AIC=11178.968, Time=1.40 sec
#  ARIMA(0,0,2)(1,0,0)[7] intercept   : AIC=11023.878, Time=1.41 sec
#  ARIMA(0,0,2)(1,0,1)[7] intercept   : AIC=10789.560, Time=3.18 sec
#  ARIMA(0,0,2)(1,0,2)[7] intercept   : AIC=10801.839, Time=6.27 sec
#  ARIMA(0,0,2)(2,0,0)[7] intercept   : AIC=10829.987, Time=2.79 sec
#  ARIMA(0,0,2)(2,0,1)[7] intercept   : AIC=inf, Time=4.56 sec
#  ARIMA(0,0,3)(0,0,0)[7] intercept   : AIC=11643.071, Time=0.64 sec
#  ARIMA(0,0,3)(0,0,1)[7] intercept   : AIC=11347.694, Time=1.75 sec
#  ARIMA(0,0,3)(0,0,2)[7] intercept   : AIC=11158.525, Time=1.89 sec
#  ARIMA(0,0,3)(1,0,0)[7] intercept   : AIC=11015.925, Time=1.78 sec
#  ARIMA(0,0,3)(1,0,1)[7] intercept   : AIC=11966.551, Time=4.21 sec
#  ARIMA(0,0,3)(2,0,0)[7] intercept   : AIC=10958.661, Time=2.95 sec
#  ARIMA(0,0,4)(0,0,0)[7] intercept   : AIC=11637.574, Time=0.67 sec
#  ARIMA(0,0,4)(0,0,1)[7] intercept   : AIC=11346.211, Time=2.04 sec
#  ARIMA(0,0,4)(1,0,0)[7] intercept   : AIC=11008.702, Time=1.74 sec
#  ARIMA(0,0,5)(0,0,0)[7] intercept   : AIC=11633.964, Time=1.09 sec
#  ARIMA(1,0,0)(0,0,0)[7] intercept   : AIC=11639.628, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[7] intercept   : AIC=11344.049, Time=0.66 sec
#  ARIMA(1,0,0)(0,0,2)[7] intercept   : AIC=11163.878, Time=1.24 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=11020.351, Time=0.90 sec
#  ARIMA(1,0,0)(1,0,1)[7] intercept   : AIC=10733.251, Time=2.32 sec
#  ARIMA(1,0,0)(1,0,2)[7] intercept   : AIC=10749.735, Time=4.48 sec
#  ARIMA(1,0,0)(2,0,0)[7] intercept   : AIC=10826.343, Time=1.95 sec
#  ARIMA(1,0,0)(2,0,1)[7] intercept   : AIC=10862.217, Time=3.31 sec
#  ARIMA(1,0,0)(2,0,2)[7] intercept   : AIC=10735.874, Time=2.95 sec
#  ARIMA(1,0,1)(0,0,0)[7] intercept   : AIC=11634.649, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,1)[7] intercept   : AIC=11191.328, Time=1.73 sec
#  ARIMA(1,0,1)(0,0,2)[7] intercept   : AIC=11030.957, Time=2.32 sec
#  ARIMA(1,0,1)(1,0,0)[7] intercept   : AIC=11000.031, Time=1.46 sec
#  ARIMA(1,0,1)(1,0,1)[7] intercept   : AIC=10803.719, Time=2.26 sec
#  ARIMA(1,0,1)(1,0,2)[7] intercept   : AIC=10791.695, Time=3.65 sec
#  ARIMA(1,0,1)(2,0,0)[7] intercept   : AIC=10796.611, Time=2.79 sec
#  ARIMA(1,0,1)(2,0,1)[7] intercept   : AIC=10803.555, Time=4.07 sec
#  ARIMA(1,0,2)(0,0,0)[7] intercept   : AIC=11390.009, Time=1.14 sec
#  ARIMA(1,0,2)(0,0,1)[7] intercept   : AIC=11139.227, Time=2.08 sec
#  ARIMA(1,0,2)(0,0,2)[7] intercept   : AIC=11000.518, Time=3.19 sec
#  ARIMA(1,0,2)(1,0,0)[7] intercept   : AIC=11007.225, Time=1.80 sec
#  ARIMA(1,0,2)(1,0,1)[7] intercept   : AIC=10784.142, Time=2.20 sec
#  ARIMA(1,0,2)(2,0,0)[7] intercept   : AIC=10833.230, Time=3.01 sec
#  ARIMA(1,0,3)(0,0,0)[7] intercept   : AIC=11378.214, Time=0.99 sec
#  ARIMA(1,0,3)(0,0,1)[7] intercept   : AIC=11128.905, Time=2.77 sec
#  ARIMA(1,0,3)(1,0,0)[7] intercept   : AIC=10937.839, Time=2.20 sec
#  ARIMA(1,0,4)(0,0,0)[7] intercept   : AIC=11301.607, Time=1.64 sec
#  ARIMA(2,0,0)(0,0,0)[7] intercept   : AIC=11638.494, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,1)[7] intercept   : AIC=11340.004, Time=0.64 sec
#  ARIMA(2,0,0)(0,0,2)[7] intercept   : AIC=11156.408, Time=1.56 sec
#  ARIMA(2,0,0)(1,0,0)[7] intercept   : AIC=11021.331, Time=1.84 sec
#  ARIMA(2,0,0)(1,0,1)[7] intercept   : AIC=10714.432, Time=2.40 sec
#  ARIMA(2,0,0)(1,0,2)[7] intercept   : AIC=10719.806, Time=3.43 sec
#  ARIMA(2,0,0)(2,0,0)[7] intercept   : AIC=10824.468, Time=3.37 sec
#  ARIMA(2,0,0)(2,0,1)[7] intercept   : AIC=inf, Time=4.85 sec
#  ARIMA(2,0,1)(0,0,0)[7] intercept   : AIC=11440.010, Time=1.00 sec
#  ARIMA(2,0,1)(0,0,1)[7] intercept   : AIC=11163.291, Time=2.23 sec
#  ARIMA(2,0,1)(0,0,2)[7] intercept   : AIC=11011.871, Time=3.26 sec
#  ARIMA(2,0,1)(1,0,0)[7] intercept   : AIC=11023.944, Time=2.44 sec
#  ARIMA(2,0,1)(1,0,1)[7] intercept   : AIC=10737.248, Time=4.00 sec
#  ARIMA(2,0,1)(2,0,0)[7] intercept   : AIC=10829.047, Time=3.84 sec
#  ARIMA(2,0,2)(0,0,0)[7] intercept   : AIC=11387.004, Time=1.68 sec
#  ARIMA(2,0,2)(0,0,1)[7] intercept   : AIC=11135.683, Time=4.95 sec
#  ARIMA(2,0,2)(1,0,0)[7] intercept   : AIC=inf, Time=3.80 sec
#  ARIMA(2,0,3)(0,0,0)[7] intercept   : AIC=11304.532, Time=1.47 sec
#  ARIMA(3,0,0)(0,0,0)[7] intercept   : AIC=11615.156, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,1)[7] intercept   : AIC=11317.498, Time=0.94 sec
#  ARIMA(3,0,0)(0,0,2)[7] intercept   : AIC=11134.986, Time=1.67 sec
#  ARIMA(3,0,0)(1,0,0)[7] intercept   : AIC=11006.100, Time=1.76 sec
#  ARIMA(3,0,0)(1,0,1)[7] intercept   : AIC=10651.633, Time=2.52 sec
#  ARIMA(3,0,0)(2,0,0)[7] intercept   : AIC=10799.110, Time=2.96 sec
#  ARIMA(3,0,1)(0,0,0)[7] intercept   : AIC=11373.717, Time=1.39 sec
#  ARIMA(3,0,1)(0,0,1)[7] intercept   : AIC=11133.784, Time=2.32 sec
#  ARIMA(3,0,1)(1,0,0)[7] intercept   : AIC=11016.781, Time=2.70 sec
#  ARIMA(3,0,2)(0,0,0)[7] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(4,0,0)(0,0,0)[7] intercept   : AIC=11604.920, Time=0.14 sec
#  ARIMA(4,0,0)(0,0,1)[7] intercept   : AIC=11310.313, Time=1.14 sec
#  ARIMA(4,0,0)(1,0,0)[7] intercept   : AIC=11005.146, Time=2.56 sec
#  ARIMA(4,0,1)(0,0,0)[7] intercept   : AIC=11320.550, Time=1.61 sec
#  ARIMA(5,0,0)(0,0,0)[7] intercept   : AIC=11544.308, Time=0.44 sec
#
# Best model:  ARIMA(3,0,0)(1,0,1)[7] intercept
# Total fit time: 203.296 seconds
#
# Training time: 203.31 seconds

# %% [markdown]
#  Akaike Information Criterion (AIC) is a statistical measure used to compare different statistical models for a given dataset. It estimates the relative amount of information lost when a particular model is used to represent the process that generated the data.

# %% [markdown]
# ## Metrics for 1 year

# %%
# Evaluate the model 1y
n_val = len(y_val)

forecast = model.predict(n_periods=n_val)

# Evaluation metrics
mse = mean_squared_error(y_val, forecast)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val, forecast)
mape_val = mape(y_val, forecast)
smape_val = smape(y_val, forecast)
r2 = r2_score(y_val, forecast)
corr = np.corrcoef(y_val, forecast)[0, 1]

print(f"MAE:   {mae:.2f}")
print(f"RMSE:  {rmse:.2f}")
print(f"MAPE:  {mape_val:.2f}%")
print(f"SMAPE: {smape_val:.2f}%")
print(f"R^2:   {r2:.2f}")
print(f"Corr:  {corr:.2f}")

print(model.summary())

model.plot_diagnostics(figsize=(16, 10))
plt.show()
# Out:
# MAE:   11.03
# RMSE:  13.70
# MAPE:  22.34%
# SMAPE: 21.79%
# R^2:   0.21
# Corr:  0.51
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1461
# Model:             SARIMAX(3, 0, 0)x(1, 0, [1], 7)   Log Likelihood               -5318.817
# Date:                             Sat, 17 May 2025   AIC                          10651.633
# Time:                                     23:27:16   BIC                          10688.641
# Sample:                                 01-01-2015   HQIC                         10665.438
#                                       - 12-31-2018
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1762      0.086      2.054      0.040       0.008       0.344
# ar.L1          0.2791      0.025     11.330      0.000       0.231       0.327
# ar.L2          0.1456      0.026      5.579      0.000       0.094       0.197
# ar.L3          0.2422      0.024      9.931      0.000       0.194       0.290
# ar.S.L7        0.9885      0.005    210.585      0.000       0.979       0.998
# ma.S.L7       -0.8278      0.019    -44.469      0.000      -0.864      -0.791
# sigma2        84.3993      2.946     28.649      0.000      78.625      90.173
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.73   Jarque-Bera (JB):                11.79
# Prob(Q):                              0.19   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                             0.17
# Prob(H) (two-sided):                  0.06   Kurtosis:                         3.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# R² = 1 -  ( Total Sum of Squares (TSS) / Sum of Squared Errors (SSE) )
#
# A Q–Q plot compares the quantiles of residuals (errors) to the quantiles of a standard normal distribution.
# - residuals are normally distributed, they will fall along a 45-degree line.

# %% [markdown]
# ## Metrics for 30 days

# %%
print(f"\n## Metrics for 30 days:")
forecast_30 = model.predict(n_periods=30)

# Evaluation metrics 30
mse = mean_squared_error(y_val[:30], forecast_30)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val[:30], forecast_30)
mape_val = mape(y_val[:30], forecast_30)
smape_val = smape(y_val[:30], forecast_30)
r2 = r2_score(y_val[:30], forecast_30)
corr = np.corrcoef(y_val[:30], forecast_30)[0, 1]

print(f"MAE:   {mae:.2f}")
print(f"RMSE:  {rmse:.2f}")
print(f"MAPE:  {mape_val:.2f}%")
print(f"SMAPE: {smape_val:.2f}%")
print(f"R^2:   {r2:.2f}")
print(f"Corr:  {corr:.2f}")
# Out:
# ## Metrics for 30 days:
# MAE:   10.96
# RMSE:  12.58
# MAPE:  30.60%
# SMAPE: 25.21%
# R^2:   -1.36
# Corr:  0.72

# %% [markdown]
# # Graph forecast vs validation

# %%
# Graph forecast vs validation
forecast_ci = model.predict(n_periods=n_val, return_conf_int=True)

forecast_values, conf_int = forecast_ci

forecast_index = y_val.index


plt.figure(figsize=(14, 5))
plt.plot(forecast_index, y_val, label="Validation", color="blue")
plt.plot(forecast_index, forecast_values, label="Forecast", color="orange")
plt.fill_between(forecast_index, conf_int[:, 0], conf_int[:, 1], 
                color='gray', alpha=0.3, label='Confidence Interval')
plt.title(f"SARIMA Forecast vs Validation ({forecast_index[0].year})")
plt.xlabel("Date")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(forecast_index, y_val, label='Actual', linewidth=2)

plt.plot(forecast_index, forecast_values, label='Predicted', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Admissions')
plt.title('Actual vs Predicted Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Actual vs Predicted admissions
plt.figure(figsize=(12, 6))
sns.scatterplot(x=y_val, y=forecast_values, alpha=0.6)

plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], color='red', linestyle='--', label='y = x')

plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title(f'Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(forecast_index[:30], y_val[:30], label='Actual', linewidth=2)

plt.plot(forecast_index[:30], forecast_values[:30], label='Predicted', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Admissions')
plt.title('30 Days: Actual vs Predicted')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Actual vs Predicted admissions (first 30 days)
plt.figure(figsize=(12, 6))
sns.scatterplot(x=y_val[:30], y=forecast_values[:30], alpha=0.6)

plt.plot([y_val[:30].min(), y_val[:30].max()], [y_val[:30].min(), y_val[:30].max()], color='red', linestyle='--', label='y = x')

plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('30 Days: Actual vs Predicted Admissions')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
