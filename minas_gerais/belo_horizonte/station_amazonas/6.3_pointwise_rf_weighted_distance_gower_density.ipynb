# %% [markdown]
# # Pointwise R. - Weighted Distance
# ## RF

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# https://towardsdatascience.com/gowers-distance-for-mixed-categorical-and-numerical-data-799fedd1080c/
import gower

# %%
# --- Metrics ---
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def smape(y_true, y_pred):
    return 100/len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# %%
df = pd.read_csv("df_final_bh_amazonas.csv")
selected_cols_final = [
    'Date',
    'DayOfWeekNum',
    'WeekOfYear',
    'Month',
    'IsWeekend',
    'IsHoliday',
    'NUMBER_INT',
    'temp_max',
    'temp_min',
    'humidity_max',
]

df_final = df[selected_cols_final].copy()
df_final = df_final.dropna()


# Marking categorical columns
categorical_cols = ['DayOfWeekNum', 'WeekOfYear', 'Month', 'IsWeekend', 'IsHoliday']
for col in categorical_cols:
    df_final[col] = df_final[col].astype('object')
df_final.dtypes
# Out:
# Date             object
# DayOfWeekNum     object
# WeekOfYear       object
# Month            object
# IsWeekend        object
# IsHoliday        object
# NUMBER_INT        int64
# temp_max        float64
# temp_min        float64
# humidity_max    float64
# dtype: object

# %%
# Simulate what gower_matrix does internally
is_number = np.vectorize(lambda x: not np.issubdtype(x, np.number))
cat_features_mask = is_number(df_final.dtypes)
print(cat_features_mask)
# Out:
# [ True  True  True  True  True  True False False False False]

# %%
df_final['Date'] = pd.to_datetime(df_final['Date'])

# remove the last 5 days (account for lag ...)
df_final = df_final[:-5]

# Range for training and testing (4 years for training, 1 year for validation)
min_year = df_final['Date'].dt.year.min()
train_mask = df_final['Date'].dt.year < (min_year + 4)
val_mask = df_final['Date'].dt.year == (min_year + 4)


df_train = df_final[train_mask]
df_val = df_final[val_mask]

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)


print(f"Training set size: {df_train.count()} rows")
print(f"Validation set size: {df_val.count()} rows")
print(f"Training set date range: {df_train['Date'].min()} to {df_train['Date'].max()}")
print(f"Validation set date range: {df_val['Date'].min()} to {df_val['Date'].max()}")

df_train = df_train.drop(columns=['Date'])
df_val = df_val.drop(columns=['Date'])

X = df_final.drop(columns=['Date', 'NUMBER_INT'])
y = df_final['NUMBER_INT']


X_train = df_train.drop(columns=['NUMBER_INT'])
y_train = df_train['NUMBER_INT']

X_val = df_val.drop(columns=['NUMBER_INT'])
y_val = df_val['NUMBER_INT']
# Out:
# Training set size: Date            1461
# DayOfWeekNum    1461
# WeekOfYear      1461
# Month           1461
# IsWeekend       1461
# IsHoliday       1461
# NUMBER_INT      1461
# temp_max        1461
# temp_min        1461
# humidity_max    1461
# dtype: int64 rows
# Validation set size: Date            360
# DayOfWeekNum    360
# WeekOfYear      360
# Month           360
# IsWeekend       360
# IsHoliday       360
# NUMBER_INT      360
# temp_max        360
# temp_min        360
# humidity_max    360
# dtype: int64 rows
# Training set date range: 2015-01-01 00:00:00 to 2018-12-31 00:00:00
# Validation set date range: 2019-01-01 00:00:00 to 2019-12-26 00:00:00

# %%
results = []

# %%
best_rf_model_base = RandomForestRegressor(
    n_estimators=20,
    max_depth=6,
    min_samples_split=16,
    random_state=9
)

best_rf_model_base.fit(X_train, y_train)

y_pred = best_rf_model_base.predict(X_val)

# Metrics 1y
mse = mean_squared_error(y_val, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val, y_pred)
mape_val = mape(y_val, y_pred)
smape_val = smape(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
corr = np.corrcoef(y_val, y_pred)[0, 1]

results.append({
    'MSE': mse,
    'RMSE': rmse,
    'MAE': mae,
    'MAPE': mape_val,
    'sMAPE': smape_val,
    'R2': r2,
    'Correlation': corr
})

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_val.index, y_val.values, label='Actual', linewidth=2)
plt.plot(y_val.index, y_pred, label='Predicted (Best Model)', linewidth=2, linestyle='--')
plt.xlabel('Time')
plt.ylabel('NUMBER_INT')
plt.title(f'Actual vs Predicted Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
results
# Out:
# [{'MSE': 118.46528724070834,
#   'RMSE': 10.88417600191711,
#   'MAE': 8.106401203057157,
#   'MAPE': 15.438129557090782,
#   'sMAPE': 16.428265889465187,
#   'R2': 0.5044579535395584,
#   'Correlation': 0.7832618681004934}]

# %%
importances = best_rf_model_base.feature_importances_
features = X.columns
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(12,6))
plt.title('Feature Importances')
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), features[indices])
plt.tight_layout()
plt.show()

# %%
importances[indices]
# Out:
# array([0.41355776, 0.21510835, 0.19030288, 0.08203985, 0.04886889,
#        0.01772122, 0.01689043, 0.01551062])

# %% [markdown]
# # Weighted Distance

# %%
# Scaler

# No scaller needed for Gower distance

# scaler = MinMaxScaler()
#scaler = StandardScaler()
# X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
# X_val_scaled = pd.DataFrame(scaler.transform(X_val), columns=X_val.columns, index=X_val.index)

# %%
X_train.dtypes
# Out:
# DayOfWeekNum     object
# WeekOfYear       object
# Month            object
# IsWeekend        object
# IsHoliday        object
# temp_max        float64
# temp_min        float64
# humidity_max    float64
# dtype: object

# %%
train_distance_matrix = gower.gower_matrix(X_train)

# Get upper triangle of the symmetric matrix (excluding diagonal)
i_upper = np.triu_indices_from(train_distance_matrix, k=1)
pairwise_distances_train = train_distance_matrix[i_upper]


percentile_number = 1
selected_percentile = np.percentile(pairwise_distances_train, percentile_number)
count_below_percentile = np.sum(pairwise_distances_train <= selected_percentile)

# Plot histogram
plt.figure(figsize=(12, 6))
plt.hist(pairwise_distances_train, bins=50, edgecolor='black', alpha=0.75)
plt.axvline(selected_percentile, color='red', linestyle='--', label=f'{percentile_number} percentile = {selected_percentile:.3f}')
plt.text(selected_percentile + 0.02, plt.ylim()[1]*0.8,
         f'{count_below_percentile:,} pairs\n≤ {selected_percentile:.3f}',
         color='red', fontsize=12, bbox=dict(facecolor='white', edgecolor='red', boxstyle='round,pad=0.3'))

plt.xlabel("Gower Distance (training instances)")
plt.ylabel("Instance Count")
plt.title("Pairwise Gower Distances")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
within_threshold = (train_distance_matrix <= selected_percentile)

# Exclude self-comparison (on the diagonal)
np.fill_diagonal(within_threshold, False)

# Count neighbors within threshold for each instance
neighbors_within_threshold = np.sum(within_threshold, axis=1)

k_max = int(np.mean(neighbors_within_threshold))
k_max
# Out:
# 14

# %%
def compute_weighted_density_reliability(distances_row, y_pred_new, y_train, min_cluster_units, tolerance, threshold):
    # --- Step 1: Density Component ---
    count = np.sum(distances_row <= threshold)
    density = min(count, min_cluster_units) / min_cluster_units

    # --- Step 2: Weighted Agreement Component ---
    sorted_indices = np.argsort(distances_row)
    selected_indices = sorted_indices[:min_cluster_units]

    selected_distances = distances_row[selected_indices]
    neighbor_targets = y_train.iloc[selected_indices]

    # Avoid division by zero
    selected_distances = np.where(selected_distances == 0, 1e-10, selected_distances)
    weights = 1 / selected_distances

    agreement_flags = np.abs(neighbor_targets - y_pred_new) < tolerance
    weighted_agreement = np.sum(weights * agreement_flags)
    total_weight = np.sum(weights)

    weighted_reliability = weighted_agreement / total_weight if total_weight > 0 else 0.0

    # --- Final Combined Reliability ---
    final_score = density * weighted_reliability
    return final_score

# %%
# Setup
final_tolerance = 8
final_min_cluster_uni = 14
final_threshold = 0.170

# %%
val_to_train_distances = gower.gower_matrix(X_val, X_train)
reliability_scores = []

for i in range(len(X_val)):
    distances_row = val_to_train_distances[i]
    y_pred_new = y_pred[i]

    score = compute_weighted_density_reliability(
        distances_row=distances_row,
        y_pred_new=y_pred_new,
        y_train=y_train,
        min_cluster_units=final_min_cluster_uni,
        tolerance=final_tolerance,
        threshold=final_threshold
    )

    print(f"Instance {i} | Predicted: {y_pred_new:.2f} | Reliability: {score:.4f}")
    reliability_scores.append(score)

df_val['Reliability'] = reliability_scores
# Out:
# Instance 0 | Predicted: 36.44 | Reliability: 0.1655
# Instance 1 | Predicted: 41.61 | Reliability: 0.9651
# Instance 2 | Predicted: 38.71 | Reliability: 0.4131
# Instance 3 | Predicted: 41.48 | Reliability: 0.7046
# Instance 4 | Predicted: 24.05 | Reliability: 0.6952
# Instance 5 | Predicted: 20.95 | Reliability: 0.7962
# Instance 6 | Predicted: 38.51 | Reliability: 0.2966
# Instance 7 | Predicted: 39.79 | Reliability: 0.4962
# Instance 8 | Predicted: 41.53 | Reliability: 0.5295
# Instance 9 | Predicted: 39.16 | Reliability: 0.2402
# Instance 10 | Predicted: 38.24 | Reliability: 0.4366
# Instance 11 | Predicted: 26.04 | Reliability: 0.9777
# Instance 12 | Predicted: 20.48 | Reliability: 0.9486
# Instance 13 | Predicted: 37.30 | Reliability: 0.6656
# Instance 14 | Predicted: 37.34 | Reliability: 0.8365
# Instance 15 | Predicted: 37.32 | Reliability: 0.7096
# Instance 16 | Predicted: 36.61 | Reliability: 0.8292
# Instance 17 | Predicted: 38.44 | Reliability: 0.8814
# Instance 18 | Predicted: 28.70 | Reliability: 0.6584
# Instance 19 | Predicted: 19.87 | Reliability: 0.7143
# Instance 20 | Predicted: 36.82 | Reliability: 0.9147
# Instance 21 | Predicted: 38.16 | Reliability: 0.6958
# Instance 22 | Predicted: 38.06 | Reliability: 0.5398
# Instance 23 | Predicted: 34.71 | Reliability: 0.8364
# Instance 24 | Predicted: 37.55 | Reliability: 0.9067
# Instance 25 | Predicted: 26.05 | Reliability: 0.8604
# Instance 26 | Predicted: 20.71 | Reliability: 0.7592
# Instance 27 | Predicted: 37.12 | Reliability: 0.6871
# Instance 28 | Predicted: 36.21 | Reliability: 0.5424
# Instance 29 | Predicted: 35.73 | Reliability: 0.3159
# Instance 30 | Predicted: 35.76 | Reliability: 0.2674
# Instance 31 | Predicted: 34.71 | Reliability: 0.1269
# Instance 32 | Predicted: 27.68 | Reliability: 0.1948
# Instance 33 | Predicted: 22.20 | Reliability: 0.3252
# Instance 34 | Predicted: 40.18 | Reliability: 0.6869
# Instance 35 | Predicted: 39.61 | Reliability: 0.8312
# Instance 36 | Predicted: 36.80 | Reliability: 0.8314
# Instance 37 | Predicted: 41.26 | Reliability: 0.8265
# Instance 38 | Predicted: 43.08 | Reliability: 0.3638
# Instance 39 | Predicted: 22.93 | Reliability: 0.7035
# Instance 40 | Predicted: 20.70 | Reliability: 0.6301
# Instance 41 | Predicted: 39.58 | Reliability: 0.6472
# Instance 42 | Predicted: 33.06 | Reliability: 0.3392
# Instance 43 | Predicted: 42.30 | Reliability: 0.7111
# Instance 44 | Predicted: 46.38 | Reliability: 0.5108
# Instance 45 | Predicted: 37.16 | Reliability: 0.6555
# Instance 46 | Predicted: 26.83 | Reliability: 0.6416
# Instance 47 | Predicted: 24.65 | Reliability: 0.6739
# Instance 48 | Predicted: 41.40 | Reliability: 0.5103
# Instance 49 | Predicted: 43.92 | Reliability: 0.4478
# Instance 50 | Predicted: 40.22 | Reliability: 0.4440
# Instance 51 | Predicted: 45.63 | Reliability: 0.2228
# Instance 52 | Predicted: 46.57 | Reliability: 0.5880
# Instance 53 | Predicted: 27.61 | Reliability: 0.8855
# Instance 54 | Predicted: 25.66 | Reliability: 0.6088
# Instance 55 | Predicted: 47.62 | Reliability: 0.2829
# Instance 56 | Predicted: 50.65 | Reliability: 0.4371
# Instance 57 | Predicted: 49.82 | Reliability: 0.2491
# Instance 58 | Predicted: 48.44 | Reliability: 0.7853
# Instance 59 | Predicted: 52.87 | Reliability: 0.6400
# Instance 60 | Predicted: 36.28 | Reliability: 0.4176
# Instance 61 | Predicted: 31.25 | Reliability: 0.8292
# Instance 62 | Predicted: 50.60 | Reliability: 0.9297
# Instance 63 | Predicted: 50.27 | Reliability: 0.6040
# Instance 64 | Predicted: 51.02 | Reliability: 0.9785
# Instance 65 | Predicted: 50.69 | Reliability: 0.6684
# Instance 66 | Predicted: 50.52 | Reliability: 0.7009
# Instance 67 | Predicted: 33.63 | Reliability: 0.4603
# Instance 68 | Predicted: 32.45 | Reliability: 0.6797
# Instance 69 | Predicted: 54.33 | Reliability: 0.3956
# Instance 70 | Predicted: 56.39 | Reliability: 0.5660
# Instance 71 | Predicted: 52.48 | Reliability: 0.5325
# Instance 72 | Predicted: 51.97 | Reliability: 0.3350
# Instance 73 | Predicted: 55.30 | Reliability: 0.7356
# Instance 74 | Predicted: 35.79 | Reliability: 0.9316
# Instance 75 | Predicted: 37.38 | Reliability: 0.4904
# Instance 76 | Predicted: 55.85 | Reliability: 0.5897
# Instance 77 | Predicted: 55.09 | Reliability: 0.6380
# Instance 78 | Predicted: 55.09 | Reliability: 0.5598
# Instance 79 | Predicted: 56.85 | Reliability: 0.7552
# Instance 80 | Predicted: 56.17 | Reliability: 0.1640
# Instance 81 | Predicted: 37.81 | Reliability: 0.7334
# Instance 82 | Predicted: 36.64 | Reliability: 0.8819
# Instance 83 | Predicted: 66.81 | Reliability: 0.1175
# Instance 84 | Predicted: 66.81 | Reliability: 0.2624
# Instance 85 | Predicted: 66.81 | Reliability: 0.5086
# Instance 86 | Predicted: 65.65 | Reliability: 0.2199
# Instance 87 | Predicted: 62.88 | Reliability: 0.5062
# Instance 88 | Predicted: 49.31 | Reliability: 0.2508
# Instance 89 | Predicted: 42.78 | Reliability: 0.1979
# Instance 90 | Predicted: 66.81 | Reliability: 0.4876
# Instance 91 | Predicted: 66.81 | Reliability: 0.5665
# Instance 92 | Predicted: 66.22 | Reliability: 0.2102
# Instance 93 | Predicted: 65.36 | Reliability: 0.8166
# Instance 94 | Predicted: 60.95 | Reliability: 0.4701
# Instance 95 | Predicted: 45.62 | Reliability: 0.6175
# Instance 96 | Predicted: 41.54 | Reliability: 0.6408
# Instance 97 | Predicted: 66.92 | Reliability: 0.6162
# Instance 98 | Predicted: 67.15 | Reliability: 0.2353
# Instance 99 | Predicted: 67.15 | Reliability: 0.2981
# Instance 100 | Predicted: 66.89 | Reliability: 0.6889
# Instance 101 | Predicted: 63.66 | Reliability: 0.6830
# Instance 102 | Predicted: 52.34 | Reliability: 0.5141
# Instance 103 | Predicted: 44.96 | Reliability: 0.3523
# Instance 104 | Predicted: 66.08 | Reliability: 0.5138
# Instance 105 | Predicted: 67.67 | Reliability: 0.4808
# Instance 106 | Predicted: 67.15 | Reliability: 0.2168
# Instance 107 | Predicted: 67.43 | Reliability: 0.7041
# Instance 108 | Predicted: 59.99 | Reliability: 0.0572
# Instance 109 | Predicted: 47.64 | Reliability: 0.4167
# Instance 110 | Predicted: 43.43 | Reliability: 0.0579
# Instance 111 | Predicted: 66.92 | Reliability: 0.6938
# Instance 112 | Predicted: 66.92 | Reliability: 0.8627
# Instance 113 | Predicted: 66.92 | Reliability: 0.1830
# Instance 114 | Predicted: 66.68 | Reliability: 0.5051
# Instance 115 | Predicted: 63.55 | Reliability: 0.2197
# Instance 116 | Predicted: 50.58 | Reliability: 0.4253
# Instance 117 | Predicted: 42.78 | Reliability: 0.6727
# Instance 118 | Predicted: 66.92 | Reliability: 0.7213
# Instance 119 | Predicted: 67.54 | Reliability: 0.3461
# Instance 120 | Predicted: 63.86 | Reliability: 0.0404
# Instance 121 | Predicted: 66.68 | Reliability: 0.5389
# Instance 122 | Predicted: 64.41 | Reliability: 0.3214
# Instance 123 | Predicted: 47.66 | Reliability: 0.2688
# Instance 124 | Predicted: 42.85 | Reliability: 0.4297
# Instance 125 | Predicted: 66.92 | Reliability: 0.4193
# Instance 126 | Predicted: 67.15 | Reliability: 0.6721
# Instance 127 | Predicted: 66.92 | Reliability: 0.5920
# Instance 128 | Predicted: 66.91 | Reliability: 0.4915
# Instance 129 | Predicted: 64.53 | Reliability: 0.5683
# Instance 130 | Predicted: 44.99 | Reliability: 0.7548
# Instance 131 | Predicted: 43.56 | Reliability: 0.2955
# Instance 132 | Predicted: 67.15 | Reliability: 0.6407
# Instance 133 | Predicted: 67.15 | Reliability: 0.6494
# Instance 134 | Predicted: 67.15 | Reliability: 0.5259
# Instance 135 | Predicted: 67.30 | Reliability: 0.8470
# Instance 136 | Predicted: 64.53 | Reliability: 0.3685
# Instance 137 | Predicted: 45.85 | Reliability: 0.8462
# Instance 138 | Predicted: 44.33 | Reliability: 0.7432
# Instance 139 | Predicted: 67.54 | Reliability: 0.7198
# Instance 140 | Predicted: 67.28 | Reliability: 0.4723
# Instance 141 | Predicted: 67.28 | Reliability: 0.4128
# Instance 142 | Predicted: 67.30 | Reliability: 0.7353
# Instance 143 | Predicted: 64.53 | Reliability: 0.7192
# Instance 144 | Predicted: 47.13 | Reliability: 0.5842
# Instance 145 | Predicted: 40.50 | Reliability: 0.5985
# Instance 146 | Predicted: 67.54 | Reliability: 0.5453
# Instance 147 | Predicted: 67.54 | Reliability: 0.7749
# Instance 148 | Predicted: 67.54 | Reliability: 0.5310
# Instance 149 | Predicted: 67.30 | Reliability: 0.8749
# Instance 150 | Predicted: 64.53 | Reliability: 0.8115
# Instance 151 | Predicted: 46.68 | Reliability: 0.4742
# Instance 152 | Predicted: 41.15 | Reliability: 0.3245
# Instance 153 | Predicted: 67.30 | Reliability: 0.8992
# Instance 154 | Predicted: 66.55 | Reliability: 0.5196
# Instance 155 | Predicted: 66.43 | Reliability: 0.3033
# Instance 156 | Predicted: 65.76 | Reliability: 0.4359
# Instance 157 | Predicted: 63.25 | Reliability: 0.2544
# Instance 158 | Predicted: 46.65 | Reliability: 0.4872
# Instance 159 | Predicted: 39.99 | Reliability: 0.6548
# Instance 160 | Predicted: 65.41 | Reliability: 0.6966
# Instance 161 | Predicted: 65.96 | Reliability: 0.4888
# Instance 162 | Predicted: 66.49 | Reliability: 0.6693
# Instance 163 | Predicted: 66.46 | Reliability: 0.5346
# Instance 164 | Predicted: 64.27 | Reliability: 0.5813
# Instance 165 | Predicted: 48.78 | Reliability: 0.7935
# Instance 166 | Predicted: 40.78 | Reliability: 0.9505
# Instance 167 | Predicted: 64.88 | Reliability: 0.7460
# Instance 168 | Predicted: 65.91 | Reliability: 0.5415
# Instance 169 | Predicted: 65.95 | Reliability: 0.7316
# Instance 170 | Predicted: 65.67 | Reliability: 0.4154
# Instance 171 | Predicted: 63.71 | Reliability: 0.6448
# Instance 172 | Predicted: 46.65 | Reliability: 0.6232
# Instance 173 | Predicted: 42.35 | Reliability: 0.7185
# Instance 174 | Predicted: 64.21 | Reliability: 0.4855
# Instance 175 | Predicted: 64.81 | Reliability: 0.6816
# Instance 176 | Predicted: 66.39 | Reliability: 0.3954
# Instance 177 | Predicted: 64.39 | Reliability: 0.2580
# Instance 178 | Predicted: 62.65 | Reliability: 0.5032
# Instance 179 | Predicted: 49.57 | Reliability: 0.4329
# Instance 180 | Predicted: 40.50 | Reliability: 0.6318
# Instance 181 | Predicted: 60.33 | Reliability: 0.8367
# Instance 182 | Predicted: 59.80 | Reliability: 0.5755
# Instance 183 | Predicted: 59.80 | Reliability: 0.7899
# Instance 184 | Predicted: 60.14 | Reliability: 0.3771
# Instance 185 | Predicted: 60.83 | Reliability: 0.4077
# Instance 186 | Predicted: 45.52 | Reliability: 0.3853
# Instance 187 | Predicted: 40.17 | Reliability: 0.1709
# Instance 188 | Predicted: 60.82 | Reliability: 0.2877
# Instance 189 | Predicted: 59.58 | Reliability: 0.2290
# Instance 190 | Predicted: 60.01 | Reliability: 0.3677
# Instance 191 | Predicted: 59.80 | Reliability: 0.3090
# Instance 192 | Predicted: 59.05 | Reliability: 0.5512
# Instance 193 | Predicted: 42.81 | Reliability: 0.3443
# Instance 194 | Predicted: 34.73 | Reliability: 0.4175
# Instance 195 | Predicted: 59.24 | Reliability: 0.7009
# Instance 196 | Predicted: 60.23 | Reliability: 0.5871
# Instance 197 | Predicted: 59.46 | Reliability: 0.6385
# Instance 198 | Predicted: 60.48 | Reliability: 0.3169
# Instance 199 | Predicted: 59.17 | Reliability: 0.7540
# Instance 200 | Predicted: 44.09 | Reliability: 0.3641
# Instance 201 | Predicted: 33.68 | Reliability: 0.7872
# Instance 202 | Predicted: 52.87 | Reliability: 0.9174
# Instance 203 | Predicted: 52.87 | Reliability: 0.9095
# Instance 204 | Predicted: 53.26 | Reliability: 0.6293
# Instance 205 | Predicted: 53.48 | Reliability: 0.8244
# Instance 206 | Predicted: 51.80 | Reliability: 0.5683
# Instance 207 | Predicted: 37.40 | Reliability: 0.4632
# Instance 208 | Predicted: 28.66 | Reliability: 0.7855
# Instance 209 | Predicted: 51.99 | Reliability: 0.5708
# Instance 210 | Predicted: 48.15 | Reliability: 0.2143
# Instance 211 | Predicted: 53.11 | Reliability: 0.3561
# Instance 212 | Predicted: 53.18 | Reliability: 0.4849
# Instance 213 | Predicted: 53.95 | Reliability: 0.3733
# Instance 214 | Predicted: 32.09 | Reliability: 0.6171
# Instance 215 | Predicted: 28.49 | Reliability: 0.6869
# Instance 216 | Predicted: 51.38 | Reliability: 0.8823
# Instance 217 | Predicted: 51.66 | Reliability: 0.3787
# Instance 218 | Predicted: 48.73 | Reliability: 0.7041
# Instance 219 | Predicted: 49.33 | Reliability: 0.3559
# Instance 220 | Predicted: 49.18 | Reliability: 0.8073
# Instance 221 | Predicted: 31.83 | Reliability: 0.5772
# Instance 222 | Predicted: 28.06 | Reliability: 0.9026
# Instance 223 | Predicted: 47.34 | Reliability: 0.7114
# Instance 224 | Predicted: 52.39 | Reliability: 0.2730
# Instance 225 | Predicted: 48.00 | Reliability: 0.4531
# Instance 226 | Predicted: 51.60 | Reliability: 0.6264
# Instance 227 | Predicted: 51.63 | Reliability: 0.5775
# Instance 228 | Predicted: 35.95 | Reliability: 0.4863
# Instance 229 | Predicted: 28.83 | Reliability: 0.7518
# Instance 230 | Predicted: 52.39 | Reliability: 0.8758
# Instance 231 | Predicted: 45.32 | Reliability: 0.2846
# Instance 232 | Predicted: 46.97 | Reliability: 0.6720
# Instance 233 | Predicted: 47.30 | Reliability: 0.4703
# Instance 234 | Predicted: 48.41 | Reliability: 0.7247
# Instance 235 | Predicted: 30.99 | Reliability: 0.4273
# Instance 236 | Predicted: 27.54 | Reliability: 0.6284
# Instance 237 | Predicted: 49.54 | Reliability: 0.8147
# Instance 238 | Predicted: 50.87 | Reliability: 0.6165
# Instance 239 | Predicted: 51.09 | Reliability: 0.7700
# Instance 240 | Predicted: 51.60 | Reliability: 0.5535
# Instance 241 | Predicted: 51.90 | Reliability: 0.2642
# Instance 242 | Predicted: 32.09 | Reliability: 0.3775
# Instance 243 | Predicted: 27.05 | Reliability: 0.4278
# Instance 244 | Predicted: 45.44 | Reliability: 0.6214
# Instance 245 | Predicted: 44.79 | Reliability: 0.6223
# Instance 246 | Predicted: 44.96 | Reliability: 0.3994
# Instance 247 | Predicted: 46.59 | Reliability: 0.7623
# Instance 248 | Predicted: 46.40 | Reliability: 0.6399
# Instance 249 | Predicted: 30.21 | Reliability: 0.1165
# Instance 250 | Predicted: 25.49 | Reliability: 0.7359
# Instance 251 | Predicted: 48.70 | Reliability: 0.8802
# Instance 252 | Predicted: 45.61 | Reliability: 0.3147
# Instance 253 | Predicted: 45.98 | Reliability: 0.2003
# Instance 254 | Predicted: 45.33 | Reliability: 0.4739
# Instance 255 | Predicted: 45.18 | Reliability: 0.3811
# Instance 256 | Predicted: 30.55 | Reliability: 0.4596
# Instance 257 | Predicted: 25.57 | Reliability: 0.7492
# Instance 258 | Predicted: 45.38 | Reliability: 0.5485
# Instance 259 | Predicted: 45.10 | Reliability: 0.6524
# Instance 260 | Predicted: 45.77 | Reliability: 0.6472
# Instance 261 | Predicted: 45.86 | Reliability: 0.2578
# Instance 262 | Predicted: 45.86 | Reliability: 0.4048
# Instance 263 | Predicted: 32.04 | Reliability: 0.2643
# Instance 264 | Predicted: 27.14 | Reliability: 0.3991
# Instance 265 | Predicted: 45.88 | Reliability: 0.6968
# Instance 266 | Predicted: 50.15 | Reliability: 0.4980
# Instance 267 | Predicted: 49.86 | Reliability: 0.1999
# Instance 268 | Predicted: 49.35 | Reliability: 0.1540
# Instance 269 | Predicted: 50.43 | Reliability: 0.2809
# Instance 270 | Predicted: 30.95 | Reliability: 0.6761
# Instance 271 | Predicted: 25.34 | Reliability: 0.4480
# Instance 272 | Predicted: 45.42 | Reliability: 0.3228
# Instance 273 | Predicted: 45.66 | Reliability: 0.7142
# Instance 274 | Predicted: 46.85 | Reliability: 0.6028
# Instance 275 | Predicted: 46.37 | Reliability: 0.3372
# Instance 276 | Predicted: 46.45 | Reliability: 0.3685
# Instance 277 | Predicted: 30.21 | Reliability: 0.7577
# Instance 278 | Predicted: 25.93 | Reliability: 0.5367
# Instance 279 | Predicted: 44.77 | Reliability: 0.8912
# Instance 280 | Predicted: 44.84 | Reliability: 0.7467
# Instance 281 | Predicted: 45.75 | Reliability: 0.5162
# Instance 282 | Predicted: 45.62 | Reliability: 0.9110
# Instance 283 | Predicted: 46.16 | Reliability: 0.9460
# Instance 284 | Predicted: 31.38 | Reliability: 0.2006
# Instance 285 | Predicted: 27.87 | Reliability: 0.4291
# Instance 286 | Predicted: 44.59 | Reliability: 0.1359
# Instance 287 | Predicted: 45.52 | Reliability: 0.1494
# Instance 288 | Predicted: 45.75 | Reliability: 0.4694
# Instance 289 | Predicted: 45.42 | Reliability: 0.7505
# Instance 290 | Predicted: 46.10 | Reliability: 0.2201
# Instance 291 | Predicted: 32.04 | Reliability: 0.4364
# Instance 292 | Predicted: 25.32 | Reliability: 0.4758
# Instance 293 | Predicted: 44.47 | Reliability: 0.7179
# Instance 294 | Predicted: 45.03 | Reliability: 0.8489
# Instance 295 | Predicted: 45.75 | Reliability: 0.4524
# Instance 296 | Predicted: 45.75 | Reliability: 0.4836
# Instance 297 | Predicted: 45.96 | Reliability: 0.4593
# Instance 298 | Predicted: 30.53 | Reliability: 0.2392
# Instance 299 | Predicted: 25.56 | Reliability: 0.2209
# Instance 300 | Predicted: 44.75 | Reliability: 0.2805
# Instance 301 | Predicted: 45.28 | Reliability: 0.3773
# Instance 302 | Predicted: 46.67 | Reliability: 0.5654
# Instance 303 | Predicted: 46.44 | Reliability: 0.7229
# Instance 304 | Predicted: 46.44 | Reliability: 0.1932
# Instance 305 | Predicted: 28.81 | Reliability: 0.1072
# Instance 306 | Predicted: 25.56 | Reliability: 0.7365
# Instance 307 | Predicted: 44.62 | Reliability: 0.3582
# Instance 308 | Predicted: 44.87 | Reliability: 0.3600
# Instance 309 | Predicted: 45.45 | Reliability: 0.2648
# Instance 310 | Predicted: 45.78 | Reliability: 0.3306
# Instance 311 | Predicted: 45.38 | Reliability: 0.3816
# Instance 312 | Predicted: 29.08 | Reliability: 0.6179
# Instance 313 | Predicted: 27.00 | Reliability: 0.6522
# Instance 314 | Predicted: 44.62 | Reliability: 0.4550
# Instance 315 | Predicted: 44.52 | Reliability: 0.3711
# Instance 316 | Predicted: 45.90 | Reliability: 0.7819
# Instance 317 | Predicted: 45.90 | Reliability: 0.5004
# Instance 318 | Predicted: 31.60 | Reliability: 0.1466
# Instance 319 | Predicted: 29.24 | Reliability: 0.7171
# Instance 320 | Predicted: 25.41 | Reliability: 0.5803
# Instance 321 | Predicted: 45.49 | Reliability: 0.8464
# Instance 322 | Predicted: 45.52 | Reliability: 0.9236
# Instance 323 | Predicted: 46.26 | Reliability: 0.3952
# Instance 324 | Predicted: 45.90 | Reliability: 0.5105
# Instance 325 | Predicted: 46.26 | Reliability: 0.3953
# Instance 326 | Predicted: 30.06 | Reliability: 0.4504
# Instance 327 | Predicted: 26.57 | Reliability: 0.5716
# Instance 328 | Predicted: 46.53 | Reliability: 0.7158
# Instance 329 | Predicted: 46.66 | Reliability: 0.8125
# Instance 330 | Predicted: 47.57 | Reliability: 0.3732
# Instance 331 | Predicted: 47.14 | Reliability: 0.4521
# Instance 332 | Predicted: 46.43 | Reliability: 0.5189
# Instance 333 | Predicted: 32.16 | Reliability: 0.5924
# Instance 334 | Predicted: 28.08 | Reliability: 0.5097
# Instance 335 | Predicted: 45.35 | Reliability: 0.5060
# Instance 336 | Predicted: 45.80 | Reliability: 0.5751
# Instance 337 | Predicted: 47.20 | Reliability: 0.6842
# Instance 338 | Predicted: 46.61 | Reliability: 0.5983
# Instance 339 | Predicted: 46.33 | Reliability: 0.6301
# Instance 340 | Predicted: 38.35 | Reliability: 0.4971
# Instance 341 | Predicted: 29.44 | Reliability: 0.4742
# Instance 342 | Predicted: 45.79 | Reliability: 0.5563
# Instance 343 | Predicted: 45.62 | Reliability: 0.8152
# Instance 344 | Predicted: 46.43 | Reliability: 0.8005
# Instance 345 | Predicted: 47.07 | Reliability: 0.8016
# Instance 346 | Predicted: 46.90 | Reliability: 0.3264
# Instance 347 | Predicted: 32.52 | Reliability: 0.4088
# Instance 348 | Predicted: 27.89 | Reliability: 0.2741
# Instance 349 | Predicted: 45.70 | Reliability: 0.8424
# Instance 350 | Predicted: 45.27 | Reliability: 0.7824
# Instance 351 | Predicted: 45.89 | Reliability: 0.7210
# Instance 352 | Predicted: 46.34 | Reliability: 0.2222
# Instance 353 | Predicted: 46.34 | Reliability: 0.4145
# Instance 354 | Predicted: 34.22 | Reliability: 0.3847
# Instance 355 | Predicted: 29.78 | Reliability: 0.2423
# Instance 356 | Predicted: 45.98 | Reliability: 0.6504
# Instance 357 | Predicted: 47.30 | Reliability: 0.4120
# Instance 358 | Predicted: 32.28 | Reliability: 0.1436
# Instance 359 | Predicted: 45.71 | Reliability: 0.8156

# %%
i = 0
distances_row = val_to_train_distances[i]
nearest_indices = np.argsort(distances_row)[:5]

print("Val instance:", X_val.iloc[i].to_dict())
print("Nearest train indices:", nearest_indices)
print("Corresponding distances:", distances_row[nearest_indices])
print("Nearest train samples:")
print(X_train.iloc[nearest_indices])
# Out:
# Val instance: {'DayOfWeekNum': 1, 'WeekOfYear': 1, 'Month': 1, 'IsWeekend': 0, 'IsHoliday': 1, 'temp_max': 27.9, 'temp_min': 19.2, 'humidity_max': 92.0}
# Nearest train indices: [ 369 1097 1096    0  733]
# Corresponding distances: [0.13718519 0.13842277 0.14511919 0.18031664 0.19870184]
# Nearest train samples:
#      DayOfWeekNum WeekOfYear Month IsWeekend IsHoliday  temp_max  temp_min  \
# 369             1          1     1         0         0      27.5      17.9
# 1097            1          1     1         0         0      29.8      19.4
# 1096            0          1     1         0         1      29.8      20.3
# 0               3          1     1         0         1      33.9      20.6
# 733             1          1     1         0         0      33.0      20.6
#
#       humidity_max
# 369           92.0
# 1097          92.0
# 1096          92.0
# 0             89.0
# 733           79.0

# %%
# Absolute prediction error
errors = np.abs(y_val.values - y_pred)

plt.figure(figsize=(12, 6))
plt.scatter(df_val['Reliability'], errors, alpha=0.6)
plt.xlabel("Reliability Score")
plt.ylabel("Absolute Error")
plt.title("Reliability Score vs. Absolute Prediction Error")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
tolerance = final_tolerance

df_plot = df_val.copy()
df_plot["y_true"] = y_val.values
df_plot["y_pred"] = y_pred
df_plot["abs_error"] = np.abs(df_plot["y_true"] - df_plot["y_pred"])

df_plot["correct"] = df_plot["abs_error"] <= tolerance

# Define reliability bins
bins = np.linspace(0, 1, 11)  # 0.0 to 1.0 in steps of 0.1
labels = [f"]{bins[i]:.2f}, {bins[i+1]:.2f}]" for i in range(len(bins)-1)]
df_plot["reliability_bin"] = pd.cut(df_plot["Reliability"], bins=bins, labels=labels, include_lowest=True)

# Group by reliability bin
grouped = df_plot.groupby("reliability_bin")
pop_count = grouped.size()
correct_count = grouped["correct"].sum()
error_rate = 1 - (correct_count / pop_count)

fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.bar(pop_count.index, pop_count.values, alpha=0.5, color='skyblue', label="Population Count")
ax1.set_ylabel("Population Count", color='black')
ax1.set_xlabel("Reliability Intervals")
ax1.tick_params(axis='x', rotation=45)

ax2 = ax1.twinx()
ax2.plot(error_rate.index, error_rate.values, marker='o', color='red', label="Error Rate")
ax2.set_ylabel("Error Rate")
ax2.set_ylim(0, 1.05)

plt.title(f"Population and Error Rate by Reliability Interval (Tolerance = ±{tolerance})")
fig.legend(loc="upper right", bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10589/2153609289.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_plot.groupby("reliability_bin")
