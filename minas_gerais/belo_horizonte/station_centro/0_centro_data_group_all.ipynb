# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
# Hospital Adm
df_hospital_adm = pd.read_csv("../data/df_b_horizonte_day.csv")
# Weather
df_weather = pd.read_csv("../data/days_weather_pampulha.csv")
# Air Q.
df_air_qual = pd.read_csv("../data/b_horizonte_pivot_centro.csv")

# Name for final dataset (save)
final_dataset_name='df_final_bh_centro.csv'

# %%
df_hospital_adm.rename(columns={"DT_INTER": 'Date'}, inplace=True)

# %%
df_hospital_adm['Date'] = pd.to_datetime(df_hospital_adm['Date'], format='%Y%m%d')
df_hospital_adm.head()
# Out:
#         Date  NUMBER_INT
# 0 2012-01-01          27
# 1 2012-01-02          41
# 2 2012-01-03          53
# 3 2012-01-04          64
# 4 2012-01-05          64

# %%
df_hospital_adm.isnull().sum()
# Out:
# Date          0
# NUMBER_INT    0
# dtype: int64

# %%
df_weather['Date'] = pd.to_datetime(df_weather['Date'])
df_weather.head()
# Out:
#         Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0 2015-01-01       Thu             3          0      33.9      20.6
# 1 2015-01-02       Fri             4          0      32.9      21.0
# 2 2015-01-03       Sat             5          1      33.5      20.2
# 3 2015-01-04       Sun             6          1      30.6      22.2
# 4 2015-01-05       Mon             0          0      30.8      20.8
#
#    humidity_max  humidity_min
# 0          89.0          32.0
# 1          87.0          38.0
# 2          83.0          38.0
# 3          81.0          43.0
# 4          79.0          36.0

# %%
df_weather_hospital_adm = pd.merge(df_weather, df_hospital_adm, on='Date', how='left')

# %%
df_weather_hospital_adm.head(20)
# Out:
#          Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0  2015-01-01       Thu             3          0      33.9      20.6
# 1  2015-01-02       Fri             4          0      32.9      21.0
# 2  2015-01-03       Sat             5          1      33.5      20.2
# 3  2015-01-04       Sun             6          1      30.6      22.2
# 4  2015-01-05       Mon             0          0      30.8      20.8
# 5  2015-01-06       Tue             1          0      29.5      20.5
# 6  2015-01-07       Wed             2          0      28.0      19.9
# 7  2015-01-08       Thu             3          0      30.4      19.7
# 8  2015-01-09       Fri             4          0      30.5      19.6
# 9  2015-01-10       Sat             5          1      32.6      20.6
# 10 2015-01-11       Sun             6          1      32.6      20.1
# 11 2015-01-12       Mon             0          0      33.3      19.7
# 12 2015-01-13       Tue             1          0      33.9      21.4
# 13 2015-01-14       Wed             2          0      32.5      21.8
# 14 2015-01-15       Thu             3          0      30.1      20.1
# 15 2015-01-16       Fri             4          0      32.4      20.9
# 16 2015-01-17       Sat             5          1      32.1      20.4
# 17 2015-01-18       Sun             6          1      32.9      18.5
# 18 2015-01-19       Mon             0          0      32.6      21.2
# 19 2015-01-20       Tue             1          0      32.7      19.9
#
#     humidity_max  humidity_min  NUMBER_INT
# 0           89.0          32.0          30
# 1           87.0          38.0          43
# 2           83.0          38.0          23
# 3           81.0          43.0          20
# 4           79.0          36.0          51
# 5           79.0          41.0          23
# 6           78.0          44.0          43
# 7           74.0          30.0          49
# 8           68.0          28.0          39
# 9           73.0          33.0          19
# 10          66.0          22.0          20
# 11          64.0          23.0          51
# 12          67.0          27.0          35
# 13          61.0          32.0          31
# 14          67.0          33.0          40
# 15          65.0          29.0          36
# 16          62.0          27.0          31
# 17          72.0          23.0          21
# 18          61.0          29.0          37
# 19          64.0          25.0          34

# %%
df_weather_hospital_adm.describe()
# Out:
#                       Date  DayOfWeekNum    IsWeekend     temp_max  \
# count                 1826   1826.000000  1826.000000  1826.000000
# mean   2017-07-01 12:00:00      3.000548     0.285871    28.314513
# min    2015-01-01 00:00:00      0.000000     0.000000    17.800000
# 25%    2016-04-01 06:00:00      1.000000     0.000000    26.300000
# 50%    2017-07-01 12:00:00      3.000000     0.000000    28.500000
# 75%    2018-09-30 18:00:00      5.000000     1.000000    30.475000
# max    2019-12-31 00:00:00      6.000000     1.000000    37.700000
# std                    NaN      2.000959     0.451952     3.044044
#
#           temp_min  humidity_max  humidity_min   NUMBER_INT
# count  1826.000000   1826.000000   1826.000000  1826.000000
# mean     17.791347     82.264513     40.261227    47.780394
# min       7.300000     42.000000     10.000000    11.000000
# 25%      16.100000     77.000000     32.000000    37.000000
# 50%      18.400000     84.000000     39.000000    47.000000
# 75%      19.700000     90.000000     48.000000    59.000000
# max      24.100000     94.000000     91.000000    94.000000
# std       2.625865      9.226503     12.646520    15.631632

# %%
df_weather_hospital_adm.isnull().sum()
# Out:
# Date            0
# DayOfWeek       0
# DayOfWeekNum    0
# IsWeekend       0
# temp_max        0
# temp_min        0
# humidity_max    0
# humidity_min    0
# NUMBER_INT      0
# dtype: int64

# %%
# Days with no hospital admi
df_weather_hospital_adm['NUMBER_INT'] = df_weather_hospital_adm['NUMBER_INT'].fillna(0.0)

# %%
df_weather_hospital_adm.isnull().sum()
# Out:
# Date            0
# DayOfWeek       0
# DayOfWeekNum    0
# IsWeekend       0
# temp_max        0
# temp_min        0
# humidity_max    0
# humidity_min    0
# NUMBER_INT      0
# dtype: int64

# %%
df_weather_hospital_adm.tail()
# Out:
#            Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 1821 2019-12-27       Fri             4          0      29.1      19.9
# 1822 2019-12-28       Sat             5          1      28.6      19.7
# 1823 2019-12-29       Sun             6          1      29.4      18.8
# 1824 2019-12-30       Mon             0          0      29.3      18.1
# 1825 2019-12-31       Tue             1          0      29.9      18.8
#
#       humidity_max  humidity_min  NUMBER_INT
# 1821          83.0          40.0          48
# 1822          88.0          44.0          39
# 1823          90.0          40.0          36
# 1824          84.0          32.0          41
# 1825          79.0          37.0          49

# %%
df_air_qual.head()
# Out:
#          Data   CO  MP10    O3  MP2.5  SO2
# 0  01/01/2015  NaN  12.0  54.0    NaN  8.0
# 1  01/01/2016  0.0  17.0  42.0    NaN  0.0
# 2  01/01/2018  NaN  26.0  29.0   10.0  0.0
# 3  01/01/2019  0.0  16.0  34.0    4.0  0.0
# 4  01/01/2020  0.0  11.0  40.0    NaN  2.0

# %%
# df_air_qual['Data'] = pd.to_datetime(df_air_qual['Data'], format='%d/%m/%Y').dt.strftime('%Y%m%d').astype(int)
df_air_qual['Data'] = pd.to_datetime(df_air_qual['Data'], format='%d/%m/%Y')

df_air_qual.head(20)
# Out:
#          Data   CO  MP10    O3  MP2.5  SO2
# 0  2015-01-01  NaN  12.0  54.0    NaN  8.0
# 1  2016-01-01  0.0  17.0  42.0    NaN  0.0
# 2  2018-01-01  NaN  26.0  29.0   10.0  0.0
# 3  2019-01-01  0.0  16.0  34.0    4.0  0.0
# 4  2020-01-01  0.0  11.0  40.0    NaN  2.0
# 5  2021-01-01  0.0   6.0  55.0    NaN  8.0
# 6  2022-01-01  0.0   NaN  22.0   11.0  0.0
# 7  2015-02-01  0.0  14.0  54.0    NaN  2.0
# 8  2016-02-01  0.0  10.0  38.0    4.0  2.0
# 9  2017-02-01  0.0  11.0  36.0    7.0  2.0
# 10 2018-02-01  0.0  12.0  22.0    NaN  NaN
# 11 2019-02-01  0.0  26.0  50.0    8.0  2.0
# 12 2020-02-01  1.0  26.0  41.0    6.0  NaN
# 13 2021-02-01  0.0  17.0  33.0   11.0  4.0
# 14 2022-02-01  1.0  22.0  26.0   11.0  0.0
# 15 2015-03-01  0.0   NaN   NaN    NaN  NaN
# 16 2016-03-01  0.0   9.0  27.0    6.0  2.0
# 17 2017-03-01  0.0   9.0  46.0    NaN  2.0
# 18 2018-03-01  0.0  23.0  56.0    6.0  2.0
# 19 2019-03-01  1.0  22.0   NaN    6.0  2.0

# %%
df_air_qual.rename(columns={'Data': 'Date'}, inplace= True)

# %%
df_weather_hospital_adm_air_qual = pd.merge(df_weather_hospital_adm, df_air_qual, on='Date', how='left')

# %%
df_weather_hospital_adm_air_qual.head()
# Out:
#         Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0 2015-01-01       Thu             3          0      33.9      20.6
# 1 2015-01-02       Fri             4          0      32.9      21.0
# 2 2015-01-03       Sat             5          1      33.5      20.2
# 3 2015-01-04       Sun             6          1      30.6      22.2
# 4 2015-01-05       Mon             0          0      30.8      20.8
#
#    humidity_max  humidity_min  NUMBER_INT   CO  MP10    O3  MP2.5   SO2
# 0          89.0          32.0          30  NaN  12.0  54.0    NaN   8.0
# 1          87.0          38.0          43  NaN  13.0  68.0    NaN  10.0
# 2          83.0          38.0          23  0.0  17.0  62.0    NaN  14.0
# 3          81.0          43.0          20  0.0  17.0  68.0    NaN  14.0
# 4          79.0          36.0          51  0.0  12.0  46.0    NaN   0.0

# %%
df_weather_hospital_adm_air_qual.tail()
# Out:
#            Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 1821 2019-12-27       Fri             4          0      29.1      19.9
# 1822 2019-12-28       Sat             5          1      28.6      19.7
# 1823 2019-12-29       Sun             6          1      29.4      18.8
# 1824 2019-12-30       Mon             0          0      29.3      18.1
# 1825 2019-12-31       Tue             1          0      29.9      18.8
#
#       humidity_max  humidity_min  NUMBER_INT   CO  MP10    O3  MP2.5  SO2
# 1821          83.0          40.0          48  0.0  14.0  38.0    NaN  2.0
# 1822          88.0          44.0          39  0.0  10.0  38.0    NaN  2.0
# 1823          90.0          40.0          36  0.0  10.0  34.0    NaN  0.0
# 1824          84.0          32.0          41  0.0   8.0  42.0    NaN  0.0
# 1825          79.0          37.0          49  0.0  10.0  37.0    NaN  2.0

# %% [markdown]
# ## export final dataset

# %%
df_weather_hospital_adm_air_qual.to_csv(final_dataset_name, index=False)

# %% [markdown]
# ## Stats

# %%
df_weather_hospital_adm_air_qual.dtypes
# Out:
# Date            datetime64[ns]
# DayOfWeek               object
# DayOfWeekNum             int64
# IsWeekend                int64
# temp_max               float64
# temp_min               float64
# humidity_max           float64
# humidity_min           float64
# NUMBER_INT               int64
# CO                     float64
# MP10                   float64
# O3                     float64
# MP2.5                  float64
# SO2                    float64
# dtype: object

# %%
df_weather_hospital_adm_air_qual.count()
# Out:
# Date            1826
# DayOfWeek       1826
# DayOfWeekNum    1826
# IsWeekend       1826
# temp_max        1826
# temp_min        1826
# humidity_max    1826
# humidity_min    1826
# NUMBER_INT      1826
# CO              1543
# MP10            1757
# O3              1659
# MP2.5           1183
# SO2             1703
# dtype: int64

# %%
df_weather_hospital_adm_air_qual.describe().T
# Out:
#                count                 mean                  min  \
# Date            1826  2017-07-01 12:00:00  2015-01-01 00:00:00
# DayOfWeekNum  1826.0             3.000548                  0.0
# IsWeekend     1826.0             0.285871                  0.0
# temp_max      1826.0            28.314513                 17.8
# temp_min      1826.0            17.791347                  7.3
# humidity_max  1826.0            82.264513                 42.0
# humidity_min  1826.0            40.261227                 10.0
# NUMBER_INT    1826.0            47.780394                 11.0
# CO            1543.0              0.18989                  0.0
# MP10          1757.0            20.038702                  2.0
# O3            1659.0             40.42616                  2.0
# MP2.5         1183.0            11.580727                  2.0
# SO2           1703.0             2.204345                  0.0
#
#                               25%                  50%                  75%  \
# Date          2016-04-01 06:00:00  2017-07-01 12:00:00  2018-09-30 18:00:00
# DayOfWeekNum                  1.0                  3.0                  5.0
# IsWeekend                     0.0                  0.0                  1.0
# temp_max                     26.3                 28.5               30.475
# temp_min                     16.1                 18.4                 19.7
# humidity_max                 77.0                 84.0                 90.0
# humidity_min                 32.0                 39.0                 48.0
# NUMBER_INT                   37.0                 47.0                 59.0
# CO                            0.0                  0.0                  0.0
# MP10                         12.0                 18.0                 25.0
# O3                           30.0                 39.0                 50.0
# MP2.5                         6.0                  8.0                 11.0
# SO2                           0.0                  2.0                  2.0
#
#                               max        std
# Date          2019-12-31 00:00:00        NaN
# DayOfWeekNum                  6.0   2.000959
# IsWeekend                     1.0   0.451952
# temp_max                     37.7   3.044044
# temp_min                     24.1   2.625865
# humidity_max                 94.0   9.226503
# humidity_min                 91.0   12.64652
# NUMBER_INT                   94.0  15.631632
# CO                            3.0   0.414837
# MP10                        116.0  12.090334
# O3                           94.0  13.599158
# MP2.5                        77.0  10.422547
# SO2                          60.0    3.64049

# %%
df_weather_hospital_adm_air_qual.describe()
# Out:
#                       Date  DayOfWeekNum    IsWeekend     temp_max  \
# count                 1826   1826.000000  1826.000000  1826.000000
# mean   2017-07-01 12:00:00      3.000548     0.285871    28.314513
# min    2015-01-01 00:00:00      0.000000     0.000000    17.800000
# 25%    2016-04-01 06:00:00      1.000000     0.000000    26.300000
# 50%    2017-07-01 12:00:00      3.000000     0.000000    28.500000
# 75%    2018-09-30 18:00:00      5.000000     1.000000    30.475000
# max    2019-12-31 00:00:00      6.000000     1.000000    37.700000
# std                    NaN      2.000959     0.451952     3.044044
#
#           temp_min  humidity_max  humidity_min   NUMBER_INT           CO  \
# count  1826.000000   1826.000000   1826.000000  1826.000000  1543.000000
# mean     17.791347     82.264513     40.261227    47.780394     0.189890
# min       7.300000     42.000000     10.000000    11.000000     0.000000
# 25%      16.100000     77.000000     32.000000    37.000000     0.000000
# 50%      18.400000     84.000000     39.000000    47.000000     0.000000
# 75%      19.700000     90.000000     48.000000    59.000000     0.000000
# max      24.100000     94.000000     91.000000    94.000000     3.000000
# std       2.625865      9.226503     12.646520    15.631632     0.414837
#
#               MP10           O3        MP2.5          SO2
# count  1757.000000  1659.000000  1183.000000  1703.000000
# mean     20.038702    40.426160    11.580727     2.204345
# min       2.000000     2.000000     2.000000     0.000000
# 25%      12.000000    30.000000     6.000000     0.000000
# 50%      18.000000    39.000000     8.000000     2.000000
# 75%      25.000000    50.000000    11.000000     2.000000
# max     116.000000    94.000000    77.000000    60.000000
# std      12.090334    13.599158    10.422547     3.640490

# %%
df_weather_hospital_adm_air_qual.isnull().sum()
# Out:
# Date              0
# DayOfWeek         0
# DayOfWeekNum      0
# IsWeekend         0
# temp_max          0
# temp_min          0
# humidity_max      0
# humidity_min      0
# NUMBER_INT        0
# CO              283
# MP10             69
# O3              167
# MP2.5           643
# SO2             123
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_weather_hospital_adm_air_qual['NUMBER_INT'], bins=20)
plt.title('Distribution of Hospitalizations')
plt.xlabel('Number of Admissions')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp_max', y='NUMBER_INT', data=df_weather_hospital_adm_air_qual)
plt.title('Temperature (Max) vs Hospitalizations')
plt.xlabel('Max Temperature (°C)')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
selected_columns = [
    'Date', 'DayOfWeekNum', 'IsWeekend', 
    'temp_max', 'temp_min', 'humidity_max', 
    'humidity_min', 'NUMBER_INT', 
    'CO', 'MP10', 'O3', 'MP2.5', 'SO2'
]

df_selected_num = df_weather_hospital_adm_air_qual[selected_columns]

correlation_matrix = df_selected_num.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df_selected_num.corr()['NUMBER_INT'].sort_values(ascending=False)
# Out:
# NUMBER_INT      1.000000
# MP10            0.169005
# CO              0.155408
# humidity_max    0.119767
# Date            0.110812
# SO2             0.097677
# MP2.5           0.090636
# humidity_min    0.035697
# O3             -0.079047
# temp_max       -0.223986
# temp_min       -0.288701
# DayOfWeekNum   -0.430371
# IsWeekend      -0.522166
# Name: NUMBER_INT, dtype: float64

# %%
weekend_vs_weekday = df_weather_hospital_adm_air_qual.groupby('IsWeekend')['NUMBER_INT'].mean()
plt.bar(['Weekday', 'Weekend'], weekend_vs_weekday)
plt.title('Average Hospitalizations: Weekday vs Weekend')
plt.ylabel('Average Admissions')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_weather_hospital_adm_air_qual['NUMBER_INT'])
plt.title('Boxplot - Number of Admissions')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='MP10', y='NUMBER_INT', data=df_weather_hospital_adm_air_qual, alpha=0.5)
plt.title('Hospitalizations vs PM10 Levels')
plt.xlabel('PM10 Levels')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp_min', y='NUMBER_INT', data=df_weather_hospital_adm_air_qual, alpha=0.5, color='orange')
plt.title('Hospitalizations vs Minimum Temperature')
plt.xlabel('Minimum Temperature (°C)')
plt.ylabel('Number of Admissions')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(25, 8))

df_weather_hospital_adm_air_qual_copy = df_weather_hospital_adm_air_qual.copy()

df_weather_hospital_adm_air_qual_copy['Date'] = pd.to_datetime(df_weather_hospital_adm_air_qual_copy['Date'], format='%Y%m%d')

features_plot = [
    'temp_max', 'temp_min', 'NUMBER_INT',
    'CO', 'MP10', 'O3', 'MP2.5', 'SO2'
]



for feature in features_plot:
    plt.plot(df_weather_hospital_adm_air_qual_copy['Date'], 
             df_weather_hospital_adm_air_qual_copy[feature], 
             label=feature)

plt.title('Trends of Key Features Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 8))

features_plot_with_day = [
    'DayOfWeekNum',
    'temp_max', 
    'temp_min', 
    'NUMBER_INT'
]



for feature in features_plot_with_day:
    plt.plot(df_weather_hospital_adm_air_qual_copy['Date'], 
             df_weather_hospital_adm_air_qual_copy[feature], 
             label=feature)

plt.title('Trends of Key Features Over Time')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
weekdays_avg = df_weather_hospital_adm_air_qual.groupby('DayOfWeekNum')['NUMBER_INT'].mean()

day_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.figure(figsize=(8, 5))
plt.bar(day_labels, weekdays_avg)
plt.title('Average Hospitalizations by Day of the Week')
plt.ylabel('Average Admissions')
plt.show()
