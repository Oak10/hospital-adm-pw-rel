# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('m_gerais_2012_2019.csv', sep=',')

# %%
df.head()
# Out:
#            N_AIH  SEXO  DT_INTER  DT_SAIDA DIAG_PRINC  IDADE  DIAS_PERM  \
# 0  3112103239510     1  20120924  20120928       J189     84          4
# 1  3112103113240     3  20120913  20120915       J219      9          2
# 2  3112103142160     3  20120915  20120919       J189      2          4
# 3  3112103185720     1  20120918  20120922       J068      7          4
# 4  3112103000479     3  20120829  20120831       J960     84          2
#
#    MORTE  res_CODIGO_UF  int_MUNCOD int_MUNNOMEX  int_CODIGO_UF  \
# 0      0             31      314390       MURIAE             31
# 1      0             31      314390       MURIAE             31
# 2      0             31      314390       MURIAE             31
# 3      0             31      314390       MURIAE             31
# 4      1             31      314390       MURIAE             31
#
#    ano_internacao def_cir_int def_micro_int  \
# 0            2012      Muriaé        Muriaé
# 1            2012      Muriaé        Muriaé
# 2            2012      Muriaé        Muriaé
# 3            2012      Muriaé        Muriaé
# 4            2012      Muriaé        Muriaé
#
#                           def_procedimento_realizado  \
# 0      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 1  TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS...
# 2      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 3  TRATAMENTO DE INFECCOES AGUDAS DAS VIAS AEREAS...
# 4  TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPI...
#
#                     def_diag_princ_cap  \
# 0  X. Doenças do aparelho respiratório
# 1  X. Doenças do aparelho respiratório
# 2  X. Doenças do aparelho respiratório
# 3  X. Doenças do aparelho respiratório
# 4  X. Doenças do aparelho respiratório
#
#                                 def_diag_princ_grupo
# 0                      Influenza [gripe] e pneumonia
# 1  Outras infecções agudas das vias aéreas inferi...
# 2                      Influenza [gripe] e pneumonia
# 3        Infecções agudas das vias aéreas superiores
# 4            Outras doenças do aparelho respiratório

# %%
print("Data set shape: ",df.shape)
print("Number of Duplicates: ",df.duplicated().sum())
print("Nmber of NaN:", df.isna().sum().sum())
# Out:
# Data set shape:  (1037718, 18)
# Number of Duplicates:  0
# Nmber of NaN: 0

# %%
df['int_CODIGO_UF'].unique()
# Out:
# array([31])

# %%
df['int_MUNCOD'].unique().size
# Out:
# 398

# %%
# Uberlândia
df[df['int_MUNCOD'] == 317020].shape[0]
# Out:
# 29178

# %%
# Belo Horizonte
df[df['int_MUNCOD'] == 310620].shape[0]
# Out:
# 143498

# %%
# betim 
df[df['int_MUNCOD'] == 310670].shape[0]
# Out:
# 8574

# %%
df_betim = df[df['int_MUNCOD'] == 310670].copy()

# %%
df_betim.head()
# Out:
#               N_AIH  SEXO  DT_INTER  DT_SAIDA DIAG_PRINC  IDADE  DIAS_PERM  \
# 7806  3112110778975     3  20120902  20120926       J189     74         24
# 7807  3112110778150     3  20120905  20120910       J219      4          5
# 7808  3112110778953     3  20120908  20120914       J040      7          6
# 7809  3112110779239     3  20120908  20120925       J189      1         17
# 7810  3112110779503     3  20120909  20120915       J960      1          6
#
#       MORTE  res_CODIGO_UF  int_MUNCOD int_MUNNOMEX  int_CODIGO_UF  \
# 7806      1             31      310670        BETIM             31
# 7807      0             31      310670        BETIM             31
# 7808      0             31      310670        BETIM             31
# 7809      0             31      310670        BETIM             31
# 7810      0             31      310670        BETIM             31
#
#       ano_internacao def_cir_int def_micro_int  \
# 7806            2012       Betim   B Horizonte
# 7807            2012       Betim   B Horizonte
# 7808            2012       Betim   B Horizonte
# 7809            2012       Betim   B Horizonte
# 7810            2012       Betim   B Horizonte
#
#                              def_procedimento_realizado  \
# 7806      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 7807  TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS...
# 7808  TRATAMENTO DE INFECCOES AGUDAS DAS VIAS AEREAS...
# 7809      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 7810  TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPI...
#
#                        def_diag_princ_cap  \
# 7806  X. Doenças do aparelho respiratório
# 7807  X. Doenças do aparelho respiratório
# 7808  X. Doenças do aparelho respiratório
# 7809  X. Doenças do aparelho respiratório
# 7810  X. Doenças do aparelho respiratório
#
#                                    def_diag_princ_grupo
# 7806                      Influenza [gripe] e pneumonia
# 7807  Outras infecções agudas das vias aéreas inferi...
# 7808        Infecções agudas das vias aéreas superiores
# 7809                      Influenza [gripe] e pneumonia
# 7810            Outras doenças do aparelho respiratório

# %%
df_betim.head()
# Out:
#               N_AIH  SEXO  DT_INTER  DT_SAIDA DIAG_PRINC  IDADE  DIAS_PERM  \
# 7806  3112110778975     3  20120902  20120926       J189     74         24
# 7807  3112110778150     3  20120905  20120910       J219      4          5
# 7808  3112110778953     3  20120908  20120914       J040      7          6
# 7809  3112110779239     3  20120908  20120925       J189      1         17
# 7810  3112110779503     3  20120909  20120915       J960      1          6
#
#       MORTE  res_CODIGO_UF  int_MUNCOD int_MUNNOMEX  int_CODIGO_UF  \
# 7806      1             31      310670        BETIM             31
# 7807      0             31      310670        BETIM             31
# 7808      0             31      310670        BETIM             31
# 7809      0             31      310670        BETIM             31
# 7810      0             31      310670        BETIM             31
#
#       ano_internacao def_cir_int def_micro_int  \
# 7806            2012       Betim   B Horizonte
# 7807            2012       Betim   B Horizonte
# 7808            2012       Betim   B Horizonte
# 7809            2012       Betim   B Horizonte
# 7810            2012       Betim   B Horizonte
#
#                              def_procedimento_realizado  \
# 7806      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 7807  TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS...
# 7808  TRATAMENTO DE INFECCOES AGUDAS DAS VIAS AEREAS...
# 7809      TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)
# 7810  TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPI...
#
#                        def_diag_princ_cap  \
# 7806  X. Doenças do aparelho respiratório
# 7807  X. Doenças do aparelho respiratório
# 7808  X. Doenças do aparelho respiratório
# 7809  X. Doenças do aparelho respiratório
# 7810  X. Doenças do aparelho respiratório
#
#                                    def_diag_princ_grupo
# 7806                      Influenza [gripe] e pneumonia
# 7807  Outras infecções agudas das vias aéreas inferi...
# 7808        Infecções agudas das vias aéreas superiores
# 7809                      Influenza [gripe] e pneumonia
# 7810            Outras doenças do aparelho respiratório

# %%
df_betim['def_procedimento_realizado'].unique()
# Out:
# array(['TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)',
#        'TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES',
#        'TRATAMENTO DE INFECCOES AGUDAS DAS VIAS AEREAS SUPERIORES',
#        'TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPIRATORIO',
#        'TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES',
#        'AMIGDALECTOMIA COM ADENOIDECTOMIA', 'ADENOIDECTOMIA',
#        'EXERESE DE PAPILOMA EM LARINGE',
#        'TRATAMENTO C/ CIRURGIAS MULTIPLAS',
#        'TORACOSTOMIA COM DRENAGEM PLEURAL FECHADA', 'AMIGDALECTOMIA',
#        'TRAQUEOSTOMIA', 'DRENAGEM DE ABSCESSO FARINGEO',
#        'DIAGNOSTICO E/OU ATENDIMENTO DE URGENCIA EM CLINICA MEDICA',
#        'BULECTOMIA UNI OU BILATERAL',
#        'TRATAMENTO DE EDEMA AGUDO DE PULMAO', 'PLEURODESE',
#        'DESCORTICACAO PULMONAR', 'SINUSOTOMIA TRANSMAXILAR',
#        'TRATAMENTO DE COAGULO RETIDO INTRATORACICO (QUALQUER VIA)',
#        'BIOPSIA DE PLEURA (POR ASPIRACAO/AGULHA / PLEUROSCOPIA)',
#        'TURBINECTOMIA', 'SEPTOPLASTIA PARA CORRECAO DE DESVIO',
#        'TRATAMENTO DE DOENCAS RESPIRATORIAS QUE AFETAM PRINCIPALMENTE O INTERSTICIO',
#        'TRATAMENTO DE INTERCORRENCIAS CLINICAS DE PACIENTE ONCOLOGICO',
#        'DRENAGEM DE ABSCESSO PERIAMIGDALIANO',
#        'TRATAMENTO CIRURGICO EM POLITRAUMATIZADO',
#        'DIAGNOSTICO E/OU ATENDIMENTO DE URGENCIA EM CLINICA PEDIATRICA',
#        'TRATAMENTO DE OUTRAS DOENCAS DAS VIAS AEREAS SUPERIORES',
#        'DIAGNOSTICO E/OU ATENDIMENTO DE URGENCIA EM CLINICA CIRURGICA',
#        'LOBECTOMIA PULMONAR', 'TRATAMENTO DE OUTRAS DOENCAS DA PLEURA',
#        'PNEUMORRAFIA', 'TRATAMENTO CIRURGICO DE RINITE CRONICA (OZENA)',
#        'TRAQUEOPLASTIA E/OU LARINGOTRAQUEOPLASTIA',
#        'TRATAMENTO CIRURGICO DE FISTULA BRONCOPLEURAL COM AMPUTACAO DE COTO BRONQUICO',
#        'TRATAMENTO DE OUTRAS DOENCAS BACTERIANAS',
#        'TRATAMENTO DE COMPLICACOES DE PROCEDIMENTOS CIRURGICOS OU CLINICOS',
#        'TRAQUEOSTOMIA TRANSTUMORAL EM ONCOLOGIA',
#        'DRENAGEM TUBULAR PLEURAL ABERTA (PLEUROSTOMIA)',
#        'TRATAMENTO DE COMPLICACOES RELACIONADAS PREDOMINANTEMENTE AO PUERPERIO',
#        'TRATAMENTO DE ESTREPTOCOCCIAS',
#        'TRATAMENTO DE INFARTO AGUDO DO MIOCARDIO',
#        'TRATAMENTO DE INTERCORRENCIAS CLINICAS NA GRAVIDEZ',
#        'TRAQUEORRAFIA E/OU FECHAMENTO DE FISTULA TRAQUEO-CUTANEA',
#        'EXERESE DE CISTO BRANQUIAL',
#        'TRATAMENTO DE OUTROS TRANSTORNOS ORIGINADOS NO PERIODO PERINATAL',
#        'OUTROS PROCEDIMENTOS COM CIRURGIAS SEQUENCIAIS',
#        'DERIVACAO VENTRICULAR EXTERNAR-SUBGALEAL EXTERNA',
#        'TRATAMENTO DAS DOENCAS PULMONARES DEVIDO A AGENTES EXTERNOS',
#        'TRATAMENTO CIRURGICO DE FISTULA E CISTOS ORO-MAXILARES',
#        'TRATAMENTO CIRURGICO DE FRATURA TRANSTROCANTERIANA',
#        'RESSECCAO DE MUCOCELE FRONTAL',
#        'TRATAMENTO DE INTERCORRENCIA EM PACIENTE RENAL CRONICO SOB TRATAMENTO DIALITICO ( POR DIA)',
#        'TIREOIDECTOMIA TOTAL',
#        'TRATAMENTO DE CRISES EPILETICAS NAO CONTROLADAS',
#        'TRATAMENTO DE INTOXICACAO OU ENVENENAMENTO POR EXPOSICAO A MEDICAMENTO E SUBSTANCIAS DE USO NAO MEDI',
#        'TRATAMENTO DE PARADA CARDIACA C/ RESSUSCITACAO',
#        'TRATAMENTO CIRURGICO DE FISTULA ORO-SINUSAL / ORO-NASAL',
#        'TRATAMENTO DE TRANSTORNOS RESPIRATORIOS E CARDIOVASCULARES ESPECIFICOS DO PERIODO NEONATAL',
#        'TRATAMENTO DAS AFECCOES NECROTICAS E SUPURATIVAS DAS VIAS AEREAS INFERIORES',
#        'AMPUTACAO / DESARTICULACAO DE DEDO',
#        'TRATAMENTO DE INSUFICIENCIA ARTERIAL C/ ISQUEMIA CRITICA',
#        'TRATAMENTO CLINICO DE PACIENTE ONCOLOGICO',
#        'TRATAMENTO DE ACIDENTE VASCULAR CEREBRAL - AVC (ISQUEMICO OU HEMORRAGICO AGUDO)',
#        'TIREOIDECTOMIA TOTAL EM ONCOLOGIA',
#        'TRATAMENTO DE CHOQUE CARDIOGENICO',
#        'TRATAMENTO CLINICO/CONSERVADOR DE TRAUMATISMOS DE QUALQUER LOCALIZACAO',
#        'RESSECCAO DE TUMOR DO MEDIASTINO', 'TORACOTOMIA EXPLORADORA',
#        'TRATAMENTO DA MIGRANEA COMPLICADA', 'LAPAROTOMIA EXPLORADORA',
#        'TRATAMENTO DE TRAUMATISMOS ENVOLVENDO MULTIPLAS REGIOES DO CORPO',
#        'TRATAMENTO DE INSUFICIENCIA CARDIACA',
#        'TRATAMENTO DE OUTRAS DOENCAS DO APARELHO DIGESTIVO',
#        'VIDEOTORACOSCOPIA'], dtype=object)

# %%
df_betim['def_procedimento_realizado'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_betim['def_procedimento_realizado'].value_counts()
# Out:
# def_procedimento_realizado
# TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)                       3100
# TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES          1288
# TRATAMENTO C/ CIRURGIAS MULTIPLAS                                   1129
# AMIGDALECTOMIA COM ADENOIDECTOMIA                                    821
# TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES     552
#                                                                     ...
# LAPAROTOMIA EXPLORADORA                                                1
# TRATAMENTO DE TRAUMATISMOS ENVOLVENDO MULTIPLAS REGIOES DO CORPO       1
# TRATAMENTO DE INSUFICIENCIA CARDIACA                                   1
# TRATAMENTO DE OUTRAS DOENCAS DO APARELHO DIGESTIVO                     1
# VIDEOTORACOSCOPIA                                                      1
# Name: count, Length: 76, dtype: int64

# %%
df_betim['def_procedimento_realizado'].value_counts(normalize=True)
# Out:
# def_procedimento_realizado
# TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)                       0.361558
# TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES          0.150222
# TRATAMENTO C/ CIRURGIAS MULTIPLAS                                   0.131677
# AMIGDALECTOMIA COM ADENOIDECTOMIA                                   0.095755
# TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES    0.064381
#                                                                       ...
# LAPAROTOMIA EXPLORADORA                                             0.000117
# TRATAMENTO DE TRAUMATISMOS ENVOLVENDO MULTIPLAS REGIOES DO CORPO    0.000117
# TRATAMENTO DE INSUFICIENCIA CARDIACA                                0.000117
# TRATAMENTO DE OUTRAS DOENCAS DO APARELHO DIGESTIVO                  0.000117
# VIDEOTORACOSCOPIA                                                   0.000117
# Name: proportion, Length: 76, dtype: float64

# %% [markdown]
# # Group by day

# %%
result_df = df_betim.groupby('DT_INTER').size().reset_index(name='NUMBER_INT')

result_df.head(25)
# Out:
#     DT_INTER  NUMBER_INT
# 0   20120101           2
# 1   20120102           1
# 2   20120103           1
# 3   20120104           3
# 4   20120105           1
# 5   20120106           5
# 6   20120107           4
# 7   20120108           1
# 8   20120109           5
# 9   20120110           8
# 10  20120111           8
# 11  20120112           6
# 12  20120113           7
# 13  20120114           2
# 14  20120115           2
# 15  20120116           4
# 16  20120117           7
# 17  20120118          11
# 18  20120119           4
# 19  20120120           8
# 20  20120121           3
# 21  20120122           4
# 22  20120123           6
# 23  20120124           5
# 24  20120125           6

# %%
# Save
result_df.to_csv('df_betim.csv', index=False)

# %%
result_df.describe()
# Out:
#            DT_INTER   NUMBER_INT
# count  2.560000e+03  2560.000000
# mean   2.015584e+07     3.349219
# std    2.313981e+04     2.277178
# min    2.012010e+07     1.000000
# 25%    2.014010e+07     2.000000
# 50%    2.016012e+07     3.000000
# 75%    2.018013e+07     5.000000
# max    2.019123e+07    15.000000

# %%
result_df['DT_INTER'] = pd.to_datetime(result_df['DT_INTER'], format='%Y%m%d')

# %%
result_df.head()
# Out:
#     DT_INTER  NUMBER_INT
# 0 2012-01-01           2
# 1 2012-01-02           1
# 2 2012-01-03           1
# 3 2012-01-04           3
# 4 2012-01-05           1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
plt.plot(result_df['DT_INTER'], result_df['NUMBER_INT'], marker='o')
plt.title('Hospitalizations Over Time')
plt.xlabel('Date of Admission (DT_INTER)')
plt.ylabel('Number of Admissions')
plt.show()

# %%
result_df.isnull().sum()
# Out:
# DT_INTER      0
# NUMBER_INT    0
# dtype: int64
