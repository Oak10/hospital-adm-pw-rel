# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('m_gerais_2012_2019.csv', sep=',')

# %%
df.head()
# Out:
#            N_AIH  SEXO  DT_INTER  DT_SAIDA DIAG_PRINC  IDADE  DIAS_PERM  \
# 0  3112103239510     1  20120924  20120928       J189     84          4
# 1  3112103113240     3  20120913  20120915       J219      9          2
# 2  3112103142160     3  20120915  20120919       J189      2          4
# 3  3112103185720     1  20120918  20120922       J068      7          4
# 4  3112103000479     3  20120829  20120831       J960     84          2
#
#    MORTE  res_CODIGO_UF  int_MUNCOD int_MUNNOMEX  int_CODIGO_UF  \
# 0      0             31      314390       MURIAE             31
# 1      0             31      314390       MURIAE             31
# 2      0             31      314390       MURIAE             31
# 3      0             31      314390       MURIAE             31
# 4      1             31      314390       MURIAE             31
#
#    ano_internacao def_cir_int def_micro_int  \
# 0            2012      Muriaé        Muriaé
# 1            2012      Muriaé        Muriaé
# ...

# %%
print("Data set shape: ",df.shape)
print("Number of Duplicates: ",df.duplicated().sum())
print("Nmber of NaN:", df.isna().sum().sum())
# Out:
# Data set shape:  (1037718, 18)
# Number of Duplicates:  0
# Nmber of NaN: 0

# %%
df['int_CODIGO_UF'].unique()
# Out:
# array([31])

# %%
df['int_MUNCOD'].unique().size
# Out:
# 398

# %%
# Uberlândia
df[df['int_MUNCOD'] == 317020].shape[0]
# Out:
# 29178

# %%
# Belo Horizonte
df[df['int_MUNCOD'] == 310620].shape[0]
# Out:
# 143498

# %%
df_belo_horizonte = df[df['int_MUNCOD'] == 310620].copy()

# %%
df_belo_horizonte.head()
# Out:
#               N_AIH  SEXO  DT_INTER  DT_SAIDA DIAG_PRINC  IDADE  DIAS_PERM  \
# 6300  3112109511214     3  20121005  20121016       J985     60         11
# 6301  3112109446787     1  20120927  20120927       J348     28          0
# 6302  3112109509333     3  20121011  20121012       J348     62          1
# 6303  3112109493911     3  20121004  20121004       J342     54          0
# 6304  3112107203931     1  20120717  20120720        J36     28          3
#
#       MORTE  res_CODIGO_UF  int_MUNCOD    int_MUNNOMEX  int_CODIGO_UF  \
# 6300      0             31      310620  BELO HORIZONTE             31
# 6301      0             31      310620  BELO HORIZONTE             31
# 6302      0             31      310620  BELO HORIZONTE             31
# 6303      0             31      310620  BELO HORIZONTE             31
# 6304      0             31      310620  BELO HORIZONTE             31
#
#       ano_internacao               def_cir_int def_micro_int  \
# ...

# %%
df_belo_horizonte['def_procedimento_realizado'].unique()
# Out:
# array(['MEDIASTINOTOMIA EXPLORADORA PARA-ESTERNAL / POR VIA ANTERIOR',
#        'TRATAMENTO CIRURGICO DE PERFURACAO DO SEPTO NASAL',
#        'TRATAMENTO C/ CIRURGIAS MULTIPLAS',
#        'DRENAGEM DE ABSCESSO PERIAMIGDALIANO',
#        'TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPIRATORIO',
#        'TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)',
#        'TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES',
#        'TRATAMENTO DE INFECCOES AGUDAS DAS VIAS AEREAS SUPERIORES',
#        'TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES',
#        'AMIGDALECTOMIA COM ADENOIDECTOMIA', 'ADENOIDECTOMIA',
#        'DIAGNOSTICO E/OU ATENDIMENTO DE URGENCIA EM CLINICA PEDIATRICA',
#        'TRATAMENTO DE EDEMA AGUDO DE PULMAO',
#        'TRATAMENTO DE OUTRAS DOENCAS DA PLEURA', 'PLEUROSTOMIA',
#        'SEPTOPLASTIA REPARADORA NAO ESTETICA',
#        'RINOPLASTIA PARA DEFEITOS POS-TRAUMATICOS',
#        'TRATAMENTO DE ESTREPTOCOCCIAS', 'DESCORTICACAO PULMONAR',
# ...

# %%
df_belo_horizonte['def_procedimento_realizado'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_belo_horizonte['def_procedimento_realizado'].value_counts()
# Out:
# def_procedimento_realizado
# TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)                       53430
# TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES          34648
# TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES     9821
# TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPIRATORIO                5802
# AMIGDALECTOMIA COM ADENOIDECTOMIA                                    5548
#                                                                     ...
# TORACECTOMIA SEM RECONSTRUCAO PARIETAL                                  1
# TRATAMENTO DE CHOQUE ANAFILATICO                                        1
# TRATAMENTO CIRURGICO DE REFLUXO GASTROESOFAGICO                         1
# HERNIOPLASTIA DIAFRAGMATICA (VIA ABDOMINAL)                             1
# ANGIOPLASTIA INTRALUMINAL DE VASOS DAS EXTREMIDADES (SEM STENT)         1
# Name: count, Length: 278, dtype: int64

# %%
df_belo_horizonte['def_procedimento_realizado'].value_counts(normalize=True)
# Out:
# def_procedimento_realizado
# TRATAMENTO DE PNEUMONIAS OU INFLUENZA (GRIPE)                       0.372340
# TRATAMENTO DAS DOENCAS CRONICAS DAS VIAS AEREAS INFERIORES          0.241453
# TRATAMENTO DE OUTRAS INFECCOES AGUDAS DAS VIAS AEREAS INFERIORES    0.068440
# TRATAMENTO DE OUTRAS DOENCAS DO APARELHO RESPIRATORIO               0.040433
# AMIGDALECTOMIA COM ADENOIDECTOMIA                                   0.038663
#                                                                       ...
# TORACECTOMIA SEM RECONSTRUCAO PARIETAL                              0.000007
# TRATAMENTO DE CHOQUE ANAFILATICO                                    0.000007
# TRATAMENTO CIRURGICO DE REFLUXO GASTROESOFAGICO                     0.000007
# HERNIOPLASTIA DIAFRAGMATICA (VIA ABDOMINAL)                         0.000007
# ANGIOPLASTIA INTRALUMINAL DE VASOS DAS EXTREMIDADES (SEM STENT)     0.000007
# Name: proportion, Length: 278, dtype: float64

# %% [markdown]
# # Group by day

# %%
result_df = df_belo_horizonte.groupby('DT_INTER').size().reset_index(name='NUMBER_INT')

result_df.head(25)
# Out:
#     DT_INTER  NUMBER_INT
# 0   20120101          27
# 1   20120102          41
# 2   20120103          53
# 3   20120104          64
# 4   20120105          64
# 5   20120106          63
# 6   20120107          42
# 7   20120108          35
# 8   20120109          60
# 9   20120110          46
# 10  20120111          55
# 11  20120112          39
# 12  20120113          62
# 13  20120114          36
# 14  20120115          20
# 15  20120116          61
# 16  20120117          46
# 17  20120118          62
# 18  20120119          57
# 19  20120120          53
# 20  20120121          35
# 21  20120122          34
# 22  20120123          54
# 23  20120124          66
# 24  20120125          55

# %%
# Save
result_df.to_csv('df_b_horizonte_day.csv', index=False)

# %%
result_df.describe()
# Out:
#            DT_INTER   NUMBER_INT
# count  2.922000e+03  2922.000000
# mean   2.015566e+07    49.109514
# std    2.292109e+04    16.427790
# min    2.012010e+07     9.000000
# 25%    2.013345e+07    37.000000
# 50%    2.015567e+07    48.000000
# 75%    2.017123e+07    60.000000
# max    2.019123e+07   108.000000

# %%
result_df['DT_INTER'] = pd.to_datetime(result_df['DT_INTER'], format='%Y%m%d')

# %%
result_df.head()
# Out:
#     DT_INTER  NUMBER_INT
# 0 2012-01-01          27
# 1 2012-01-02          41
# 2 2012-01-03          53
# 3 2012-01-04          64
# 4 2012-01-05          64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
plt.plot(result_df['DT_INTER'], result_df['NUMBER_INT'], marker='o')
plt.title('Hospitalizations Over Time')
plt.xlabel('Date of Admission (DT_INTER)')
plt.ylabel('Number of Admissions')
plt.show()
