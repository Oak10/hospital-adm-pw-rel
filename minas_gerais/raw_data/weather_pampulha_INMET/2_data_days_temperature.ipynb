# %% [markdown]
# # Create dataset Days + weather (Pampulha Belo Horizonte 2015 - 2019)

# %%
import pandas as pd

# %%
## DF days

# %%
date_range = pd.date_range(start='2015-01-01', end='2019-12-31', freq='D')

df = pd.DataFrame({
    'Date': date_range.strftime('%Y%m%d'),
    'DayOfWeek': date_range.strftime('%a'),
    'DayOfWeekNum': date_range.weekday,  # Monday=0, Sunday=6
    'IsWeekend': date_range.weekday.map(lambda x: 1 if x >= 5 else 0)
})


df.tail()
# df.to_csv('complete_date_dataset.csv', index=False)
# Out:
#           Date DayOfWeek  DayOfWeekNum  IsWeekend
# 1821  20191227       Fri             4          0
# 1822  20191228       Sat             5          1
# 1823  20191229       Sun             6          1
# 1824  20191230       Mon             0          0
# 1825  20191231       Tue             1          0

# %% [markdown]
# ## Add Season

# %%
# # Outono	Autumn / Fall	March 21st to June 20th
# # Inverno	Winter	June 21st to September 20th
# # Primavera	Spring	September 21st to December 20th
# # Verão	Summer	December 21st to March 20th

# def get_brazilian_season(date):
#     year = date.year
#     summer_start = pd.Timestamp(f"{year}-12-21")
#     autumn_start = pd.Timestamp(f"{year}-03-20")
#     winter_start = pd.Timestamp(f"{year}-06-21")
#     spring_start = pd.Timestamp(f"{year}-09-23")
    
#     if date >= summer_start or date < autumn_start:
#         return 'Summer'
#     elif date >= autumn_start and date < winter_start:
#         return 'Autumn'
#     elif date >= winter_start and date < spring_start:
#         return 'Winter'
#     else:
#         return 'Spring'
    
# def get_brazilian_season_num(date):
#     year = date.year
#     summer_start = pd.Timestamp(f"{year}-12-21")
#     autumn_start = pd.Timestamp(f"{year}-03-20")
#     winter_start = pd.Timestamp(f"{year}-06-21")
#     spring_start = pd.Timestamp(f"{year}-09-23")
    
#     if date >= summer_start or date < autumn_start:
#         return 4 #'Summer'
#     elif date >= autumn_start and date < winter_start:
#         return 1 #'Autumn'
#     elif date >= winter_start and date < spring_start:
#         return 2 #'Winter'
#     else:
#         return 3 #'Spring'


# df = pd.DataFrame({
#     'Date': date_range.strftime('%Y%m%d'),
#     'DayOfWeek': date_range.strftime('%a'),
#     'DayOfWeekNum': date_range.weekday,
#     'IsWeekend': date_range.weekday.map(lambda x: 1 if x >= 5 else 0),
#     'Month': date_range.month,
#     'Season': date_range.map(get_brazilian_season),
#     'SeasonNum': date_range.map(get_brazilian_season_num)
# })

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y%m%d')

# %% [markdown]
# ## Add Weather

# %%
df_temp = pd.read_csv('daily_weather_pampulha_2015_19.csv')
df_temp['Date'] = pd.to_datetime(df_temp['Date'])

df_temp.head()
# Out:
#         Date  temp_max  temp_min  humidity_max  humidity_min
# 0 2015-01-01      33.9      20.6          89.0          32.0
# 1 2015-01-02      32.9      21.0          87.0          38.0
# 2 2015-01-03      33.5      20.2          83.0          38.0
# 3 2015-01-04      30.6      22.2          81.0          43.0
# 4 2015-01-05      30.8      20.8          79.0          36.0

# %%
df_final = pd.merge(df, df_temp, on='Date', how='left')

df_final.tail(15)
# Out:
#            Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 1811 2019-12-17       Tue             1          0      31.2      20.3
# 1812 2019-12-18       Wed             2          0      32.4      20.8
# 1813 2019-12-19       Thu             3          0      30.5      19.9
# 1814 2019-12-20       Fri             4          0      30.7      19.7
# 1815 2019-12-21       Sat             5          1      29.2      20.0
# 1816 2019-12-22       Sun             6          1      32.9      20.3
# 1817 2019-12-23       Mon             0          0      25.9      19.0
# 1818 2019-12-24       Tue             1          0      24.6      17.6
# 1819 2019-12-25       Wed             2          0      30.3      17.4
# 1820 2019-12-26       Thu             3          0      30.4      20.8
# 1821 2019-12-27       Fri             4          0      29.1      19.9
# 1822 2019-12-28       Sat             5          1      28.6      19.7
# 1823 2019-12-29       Sun             6          1      29.4      18.8
# 1824 2019-12-30       Mon             0          0      29.3      18.1
# 1825 2019-12-31       Tue             1          0      29.9      18.8
#
#       humidity_max  humidity_min
# 1811          78.0          28.0
# 1812          70.0          28.0
# 1813          89.0          43.0
# 1814          88.0          42.0
# 1815          91.0          46.0
# 1816          84.0          34.0
# 1817          91.0          59.0
# 1818          91.0          65.0
# 1819          91.0          36.0
# 1820          79.0          37.0
# 1821          83.0          40.0
# 1822          88.0          44.0
# 1823          90.0          40.0
# 1824          84.0          32.0
# 1825          79.0          37.0

# %%
df_final.head(15)
# Out:
#          Date DayOfWeek  DayOfWeekNum  IsWeekend  temp_max  temp_min  \
# 0  2015-01-01       Thu             3          0      33.9      20.6
# 1  2015-01-02       Fri             4          0      32.9      21.0
# 2  2015-01-03       Sat             5          1      33.5      20.2
# 3  2015-01-04       Sun             6          1      30.6      22.2
# 4  2015-01-05       Mon             0          0      30.8      20.8
# 5  2015-01-06       Tue             1          0      29.5      20.5
# 6  2015-01-07       Wed             2          0      28.0      19.9
# 7  2015-01-08       Thu             3          0      30.4      19.7
# 8  2015-01-09       Fri             4          0      30.5      19.6
# 9  2015-01-10       Sat             5          1      32.6      20.6
# 10 2015-01-11       Sun             6          1      32.6      20.1
# 11 2015-01-12       Mon             0          0      33.3      19.7
# 12 2015-01-13       Tue             1          0      33.9      21.4
# 13 2015-01-14       Wed             2          0      32.5      21.8
# 14 2015-01-15       Thu             3          0      30.1      20.1
#
#     humidity_max  humidity_min
# 0           89.0          32.0
# 1           87.0          38.0
# 2           83.0          38.0
# 3           81.0          43.0
# 4           79.0          36.0
# 5           79.0          41.0
# 6           78.0          44.0
# 7           74.0          30.0
# 8           68.0          28.0
# 9           73.0          33.0
# 10          66.0          22.0
# 11          64.0          23.0
# 12          67.0          27.0
# 13          61.0          32.0
# 14          67.0          33.0

# %%
df_final.isna().sum()
# Out:
# Date            0
# DayOfWeek       0
# DayOfWeekNum    0
# IsWeekend       0
# temp_max        0
# temp_min        0
# humidity_max    0
# humidity_min    0
# dtype: int64

# %%
df_final.to_csv('days_weather_pampulha.csv', index=False)
